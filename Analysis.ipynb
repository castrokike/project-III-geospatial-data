# %% [markdown]
# # Office location selection
#
# For this project we will determine the best posible location for an office that satisfies all the requirements stated in the project description. Here's a summary:
#
# 1. It must be near tech startups that have raised more than 1MM USD.
# 2. It must be near other companies that do design.
# 3. It must be near schools since 1/3 of employees have at least 1 child.
# 4. It must be near an airport.
# 5. It should be near a Starbucks.
# 6. It should have nearby restaurants with vegan options.
# 7. It should have a basketball court within 10 Km.
# 8. It must have a pet grooming service nearby for the company dog.
#
# For this, we will use the companies Mongo DB provided by crunchbase.
#
# First, lets run our python script that defines the functions we will work with:

# %%
# %run -i 'python_scripts/mongo_connection.py'

# %% [markdown]
# Now lets establish the connection to our Mongo Database. For this we will use a function specified in the mongo_connection.py script.

# %%
c = connect_mongo("ironhack","companies")
c
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'companies')

# %% [markdown]
# Our connection was succesful! Now lets query our companies collection for tech startups and design companies. Again we will use functions defined for these tasks in the mongo_connection.py script since the queries are quite long.

# %%
tech = get_tech_startups(1000000,2008)
# Out:
# Query returned  274  companies.

# %%
design = get_design_companies()
# Out:
# Query returned  965  companies.

# %% [markdown]
# Now that we have our company data, lets process it to eliminate those without coordinates and transform these lists into DataFrames. For this we will use pre-defined functions in our data_process script, lets run it:

# %%
# %run -i 'python_scripts/data_process.py'

# %%
tech_data = get_offices_location(tech)
# Out:
# Received data for  333  companies.
#  202  companies with full location information left.

# %%
design_data = get_offices_location(design)
# Out:
# Received data for  1094  companies.
#  708  companies with full location information left.

# %% [markdown]
# Now that we have data for all tech and design companies that fit our criteria, lets make a heatmap of their location to see which cities have more of both. For this we will load our mappying script since it has functions that will help us map this information.

# %%
# %run -i 'python_scripts/mapping.py'

# %%
map_heatmap(tech_data, design_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9adb1b1c6655df94d045465303e2281 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9adb1b1c6655df94d045465303e2281&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9adb1b1c6655df94d045465303e2281 = L.map(
#                 &quot;map_a9adb1b1c6655df94d045465303e2281&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fc6c461d07d58e22fd33490289b36df = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9adb1b1c6655df94d045465303e2281);
#
#
#             var feature_group_3fbab004a3a00672da805a9b271d5a28 = L.featureGroup(
#                 {}
#             ).addTo(map_a9adb1b1c6655df94d045465303e2281);
#
#
#             var heat_map_0b4e4979c5bd9f43ebf3fc331a63e07d = L.heatLayer(
#                 [[51.5499708, -0.1815999], [28.5821195, 77.3266991], [37.775196, -122.419204], [37.4189073, -122.0884286], [40.723652, -73.985281], [48.8952712, 2.4476331], [32.037363, 34.8003705], [47.6257402, -122.3581623], [37.785271, -122.397582], [37.41924, -122.208414], [46.2121463, 6.1503245], [45.546481, -122.9021288], [53.544711, -113.515769], [30.310978, -81.657707], [37.758352, -122.398379], [38.960381, -77.084811], [45.5251, -122.8097], [37.775196, -122.419204], [34.153588, -118.422495], [37.775196, -122.419204], [37.764395, -122.401024], [42.35888, -71.05682], [42.337037, -71.251748], [42.3694815, -71.0771871], [34.047312, -118.445243], [47.6103008, -122.3399782], [37.78691, -122.404403], [40.741594, -73.990468], [32.88945, -117.166929], [32.037363, 34.8003705], [34.007112, -118.489748], [37.5252461, -121.9178417], [34.0497638, -118.2474287], [40.7481039, -74.0353787], [37.552262, -122.292146], [42.2968126, -71.3876282], [40.744618, -73.987764], [37.4104762, -122.0185959], [37.4239496, -122.1011815], [37.7870923, -122.3999719], [36.9751032, -122.0253784], [39.749671, -104.9998449], [51.5001524, -0.1262362], [42.4236783, -71.2459523], [37.384239, -122.012475], [42.318138, -71.24756], [42.3406534, -71.0680027], [40.739867, -73.990024], [33.8171, -111.9035], [40.5932386, -105.0766501], [37.7705096, -122.4015807], [52.5308516, 13.3842605], [40.756054, -73.986951], [40.7450497, -73.9900984], [42.392628, -71.151216], [38.6501668, -90.2598684], [40.7272544, -74.0057152], [37.788796, -122.40971], [29.9739941, -90.0822015], [37.7893215, -122.4013624], [51.5196135, -0.1020265], [32.0554, 34.7595], [37.7905538, -122.4041485], [37.4484914, -122.1802812], [40.7481039, -74.0353787], [40.7185614, -73.998662], [37.5561712, -122.0780632], [12.971606, 77.594376], [45.546481, -122.9021288], [37.566879, -122.323895], [52.143886, -106.6634565], [42.3756409, -72.5196907], [48.868478, 2.339843], [34.005914, -118.488129], [37.7795014, -122.3948712], [34.0137151, -118.4660597], [42.6751888, -71.1469003], [34.213925, -118.487236], [40.438423, -80.001933], [42.376862, -71.14462], [38.94794, -77.347961], [29.7847641, -82.4768036], [34.111471, -118.174878], [39.9443552, -75.1257381], [29.973994, -90.082202], [37.446823, -122.161523], [34.0698494, -118.4054182], [-33.947414, 150.967905], [49.2851733, -123.0952381], [51.8205815, 0.0118608], [30.297775, -97.762921], [37.393536, -122.076747], [37.443058, -122.161674], [40.73343, -73.990967], [26.2032036, -80.1510951], [37.420728, -122.2103414], [43.4496954, -80.487328], [37.764395, -122.401024], [38.257035, -85.717393], [32.7161896, -117.168697], [37.444531, -122.163352], [37.445335, -122.15833], [37.4280877, -122.143368], [37.7770719, -122.3966273], [42.3853985, -83.5069834], [42.3647559, -71.1032591], [42.275263, -71.24762], [37.444332, -122.161018], [47.490346, 19.059078], [37.3229727, -122.0385792], [30.269004, -97.740395], [41.8965162, -87.643622], [42.3624253, -71.116031], [37.523194, -122.259179], [39.749671, -104.9998449], [43.644678, -79.567221], [37.503147, -122.211435], [37.775196, -122.419204], [43.6910137, -70.2694636], [40.4225487, -3.6830316], [51.5480857, 0.6553168], [47.3912899, 8.5082891], [34.052187, -118.243425], [40.532969, -80.010645], [47.6220245, -122.3350847], [40.740308, -74.007199], [40.740231, -73.985433], [47.676762, -122.2049192], [37.770067, -122.407603], [37.6656476, -122.3843489], [37.39458, -121.928393], [37.7900992, -122.4021988], [21.303049, -157.78907], [52.132633, 5.291266], [37.781265, -122.393229], [41.3279176, -73.2435522], [41.792265, 1.996567], [37.7870923, -122.3999719], [37.78691, -122.404403], [40.741594, -73.990468], [51.51819, -0.208979], [37.270518, -121.95

# %% [markdown]
# Browsing this heatmap, it looks like our offices should be either in San francisco, Los Angeles, New york, Miami, Paris or Manchester. Let's get GeoJsons for these cities.
#
# Rather than looking for defined poligons with the borders of these cities, I created GeoJson files of circles encompassing these cities and their surrounding area. I made them wide enough so that they covered nearby towns that also have important amounts of companies.

# %%
city_names = ["san_francisco", "los_angeles", "new_york", "miami", "paris", "manchester"]
cities = load_cities(city_names)
cities
# Out:
# {'San_Francisco': <POLYGON ((-122.241 38.23, -122.312 38.227, -122.383 38.219, -122.452 38.205...>,
#  'Los_Angeles': <POLYGON ((-118.113 34.81, -118.207 34.807, -118.3 34.795, -118.392 34.776, ...>,
#  'New_York': <POLYGON ((-73.977 41.103, -74.021 41.102, -74.064 41.097, -74.107 41.089, -...>,
#  'Miami': <POLYGON ((-80.271 26.121, -80.305 26.12, -80.338 26.115, -80.371 26.108, -8...>,
#  'Paris': <POLYGON ((2.354 49.066, 2.322 49.065, 2.292 49.062, 2.261 49.057, 2.232 49....>,
#  'Manchester': <POLYGON ((-2.244 53.593, -2.263 53.593, -2.282 53.591, -2.3 53.589, -2.318 ...>}

# %% [markdown]
# Now that we have our GeoJsons loaded, lets add the city name to our DataFrames, based on these GeoJsons.
#
# This stepp will check for every office in our Data Frame, if that location is in one of the cirlces defined by the GeoJsons, it will add that city name to our DataFrame.

# %%
tech_data = add_city_name(tech_data, cities)
# We will also be adding a "tech" identifier in a new column called "type". This will be useful in a future step, where we will consolidate all of our data in a single DataFrame.
tech_data["type"] = "tech"
tech_data.head()
# Out:
#         name office description  office latitude  office longitude  \
# 0    Movirtu        Headquarter        51.549971         -0.181600
# 2    Movirtu       India Office        28.582120         77.326699
# 3     GitHub                           37.775196       -122.419204
# 5  Gridstore          Gridstore        37.418907       -122.088429
# 6    Kluster    New York Office        40.723652        -73.985281
#
#             city  type
# 0           None  tech
# 2           None  tech
# 3  San_Francisco  tech
# 5  San_Francisco  tech
# 6       New_York  tech

# %% [markdown]
# Now we will do the same thing for our desgin companies

# %%
design_data = add_city_name(design_data, cities)
design_data["type"] = "design"
design_data.head()
# Out:
#          name  office description  office latitude  office longitude  \
# 0  Technorati                            37.779558       -122.393041
# 1     AddThis       HQ - Virginia        38.926172        -77.245195
# 2     AddThis     New York Office        40.724604        -73.996876
# 3     AddThis  Los Angeles Office        34.026302       -118.380954
# 6     AddThis     Michigan Office        42.557958        -83.167884
#
#             city    type
# 0  San_Francisco  design
# 1           None  design
# 2       New_York  design
# 3    Los_Angeles  design
# 6           None  design

# %% [markdown]
# Now lets join these DataFrames and find out the top cities with more companies.

# %%
full_data = pd.concat([tech_data, design_data], axis=0)
top_cities = full_data.groupby(['city', 'type'])['name'].agg('count').reset_index()
top_cities
# Out:
#             city    type  name
# 0    Los_Angeles  design    46
# 1    Los_Angeles    tech    14
# 2     Manchester  design     3
# 3          Miami  design     7
# 4       New_York  design    80
# 5       New_York    tech    22
# 6          Paris  design    10
# 7          Paris    tech     4
# 8  San_Francisco  design   123
# 9  San_Francisco    tech    58

# %% [markdown]
# Looks like our top 3 cities with more tech and design companies are San Francisco, New York and Los Angeles. Lets drop the rest:

# %%
top_cities = top_cities.drop([2,3,6,7])
top_cities
# Out:
#             city    type  name
# 0    Los_Angeles  design    46
# 1    Los_Angeles    tech    14
# 4       New_York  design    80
# 5       New_York    tech    22
# 8  San_Francisco  design   123
# 9  San_Francisco    tech    58

# %% [markdown]
# Having narrowed down our search to these 3 cities lets map them.
# First, lets consolidate our data:

# %%
final_data = full_data[full_data['city'].isin(['Los_Angeles', 'New_York', 'San_Francisco'])]
final_data.head()
# Out:
#          name office description  office latitude  office longitude  \
# 3      GitHub                           37.775196       -122.419204
# 5   Gridstore          Gridstore        37.418907       -122.088429
# 6     Kluster    New York Office        40.723652        -73.985281
# 17       Meez                           37.785271       -122.397582
# 18     Gamook               None        37.419240       -122.208414
#
#              city  type
# 3   San_Francisco  tech
# 5   San_Francisco  tech
# 6        New_York  tech
# 17  San_Francisco  tech
# 18  San_Francisco  tech

# %% [markdown]
# Now lets map our 3 cities:

# %%
top_3_map = top_3_map(final_data)
top_3_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_679bebeff0eb4ed59cce9e8e46018480 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_679bebeff0eb4ed59cce9e8e46018480&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_679bebeff0eb4ed59cce9e8e46018480 = L.map(
#                 &quot;map_679bebeff0eb4ed59cce9e8e46018480&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cafb842f6f6a68eee74957ae58a232fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_679bebeff0eb4ed59cce9e8e46018480);
#
#
#             var feature_group_d248f207d880e9f1655ab2491a1e0fb3 = L.featureGroup(
#                 {}
#             ).addTo(map_679bebeff0eb4ed59cce9e8e46018480);
#
#
#             var marker_8fc62600265bbbdca8f740dd690f1640 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_636911cc07f79c5fb3d3bf72fb8bd9f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8fc62600265bbbdca8f740dd690f1640.setIcon(icon_636911cc07f79c5fb3d3bf72fb8bd9f0);
#
#
#             marker_8fc62600265bbbdca8f740dd690f1640.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f992f9169e9e3e7c77d54aebb61d9675 = L.marker(
#                 [37.4189073, -122.0884286],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_66ee6129ba7b944c279579151078267a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f992f9169e9e3e7c77d54aebb61d9675.setIcon(icon_66ee6129ba7b944c279579151078267a);
#
#
#             marker_f992f9169e9e3e7c77d54aebb61d9675.bindTooltip(
#                 `&lt;div&gt;
#                      Gridstore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6909f472eca0f05e14ce4d7504e41f2b = L.marker(
#                 [40.723652, -73.985281],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_394f3965ade12d3f56434d249953abf4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6909f472eca0f05e14ce4d7504e41f2b.setIcon(icon_394f3965ade12d3f56434d249953abf4);
#
#
#             marker_6909f472eca0f05e14ce4d7504e41f2b.bindTooltip(
#                 `&lt;div&gt;
#                      Kluster
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_74759229dffada75aaad64ee6747ac7f = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_9ac949b8586b73dc182265d9ab312ad3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_74759229dffada75aaad64ee6747ac7f.setIcon(icon_9ac949b8586b73dc182265d9ab312ad3);
#
#
#             marker_74759229dffada75aaad64ee6747ac7f.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1bcc7e286d55c7702aa2bdd72f986fc2 = L.marker(
#                 [37.41924, -122.208414],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_5974952cb0c61ccf5159808200b4fb5b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor

# %% [markdown]
# Browsing this map, lets focus on San Francisco since it is the city with most companies.

# %%
top_3_map.fit_bounds([[37.8,-122.4],[37.5,-122.1]], padding=(4,4))
top_3_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_679bebeff0eb4ed59cce9e8e46018480 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_679bebeff0eb4ed59cce9e8e46018480&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_679bebeff0eb4ed59cce9e8e46018480 = L.map(
#                 &quot;map_679bebeff0eb4ed59cce9e8e46018480&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cafb842f6f6a68eee74957ae58a232fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_679bebeff0eb4ed59cce9e8e46018480);
#
#
#             var feature_group_d248f207d880e9f1655ab2491a1e0fb3 = L.featureGroup(
#                 {}
#             ).addTo(map_679bebeff0eb4ed59cce9e8e46018480);
#
#
#             var marker_8fc62600265bbbdca8f740dd690f1640 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_636911cc07f79c5fb3d3bf72fb8bd9f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8fc62600265bbbdca8f740dd690f1640.setIcon(icon_636911cc07f79c5fb3d3bf72fb8bd9f0);
#
#
#             marker_8fc62600265bbbdca8f740dd690f1640.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f992f9169e9e3e7c77d54aebb61d9675 = L.marker(
#                 [37.4189073, -122.0884286],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_66ee6129ba7b944c279579151078267a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f992f9169e9e3e7c77d54aebb61d9675.setIcon(icon_66ee6129ba7b944c279579151078267a);
#
#
#             marker_f992f9169e9e3e7c77d54aebb61d9675.bindTooltip(
#                 `&lt;div&gt;
#                      Gridstore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6909f472eca0f05e14ce4d7504e41f2b = L.marker(
#                 [40.723652, -73.985281],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_394f3965ade12d3f56434d249953abf4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6909f472eca0f05e14ce4d7504e41f2b.setIcon(icon_394f3965ade12d3f56434d249953abf4);
#
#
#             marker_6909f472eca0f05e14ce4d7504e41f2b.bindTooltip(
#                 `&lt;div&gt;
#                      Kluster
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_74759229dffada75aaad64ee6747ac7f = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_9ac949b8586b73dc182265d9ab312ad3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_74759229dffada75aaad64ee6747ac7f.setIcon(icon_9ac949b8586b73dc182265d9ab312ad3);
#
#
#             marker_74759229dffada75aaad64ee6747ac7f.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1bcc7e286d55c7702aa2bdd72f986fc2 = L.marker(
#                 [37.41924, -122.208414],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_5974952cb0c61ccf5159808200b4fb5b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor

# %% [markdown]
# Let's find out the point that is closest to all of our companies. I'll calculate the mean coordinate for our tech companies and for our design companies separately and add this to our map:

# %%
sf_middle_tech = mean_coordinates(final_data[(final_data["city"] == 'San_Francisco')&(final_data["type"] == 'tech')])
sf_middle_design = mean_coordinates(final_data[(final_data["city"] == 'San_Francisco')&(final_data["type"] == 'design')])

add_marker("sf_tech_center","orange","computer",sf_middle_tech,top_3_map)
add_marker("sf_design_center","red","fa-shopping-bag",sf_middle_design,top_3_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_679bebeff0eb4ed59cce9e8e46018480 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_679bebeff0eb4ed59cce9e8e46018480&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_679bebeff0eb4ed59cce9e8e46018480 = L.map(
#                 &quot;map_679bebeff0eb4ed59cce9e8e46018480&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cafb842f6f6a68eee74957ae58a232fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_679bebeff0eb4ed59cce9e8e46018480);
#
#
#             var feature_group_d248f207d880e9f1655ab2491a1e0fb3 = L.featureGroup(
#                 {}
#             ).addTo(map_679bebeff0eb4ed59cce9e8e46018480);
#
#
#             var marker_8fc62600265bbbdca8f740dd690f1640 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_636911cc07f79c5fb3d3bf72fb8bd9f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8fc62600265bbbdca8f740dd690f1640.setIcon(icon_636911cc07f79c5fb3d3bf72fb8bd9f0);
#
#
#             marker_8fc62600265bbbdca8f740dd690f1640.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f992f9169e9e3e7c77d54aebb61d9675 = L.marker(
#                 [37.4189073, -122.0884286],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_66ee6129ba7b944c279579151078267a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f992f9169e9e3e7c77d54aebb61d9675.setIcon(icon_66ee6129ba7b944c279579151078267a);
#
#
#             marker_f992f9169e9e3e7c77d54aebb61d9675.bindTooltip(
#                 `&lt;div&gt;
#                      Gridstore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6909f472eca0f05e14ce4d7504e41f2b = L.marker(
#                 [40.723652, -73.985281],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_394f3965ade12d3f56434d249953abf4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6909f472eca0f05e14ce4d7504e41f2b.setIcon(icon_394f3965ade12d3f56434d249953abf4);
#
#
#             marker_6909f472eca0f05e14ce4d7504e41f2b.bindTooltip(
#                 `&lt;div&gt;
#                      Kluster
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_74759229dffada75aaad64ee6747ac7f = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_9ac949b8586b73dc182265d9ab312ad3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_74759229dffada75aaad64ee6747ac7f.setIcon(icon_9ac949b8586b73dc182265d9ab312ad3);
#
#
#             marker_74759229dffada75aaad64ee6747ac7f.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1bcc7e286d55c7702aa2bdd72f986fc2 = L.marker(
#                 [37.41924, -122.208414],
#                 {}
#             ).addTo(feature_group_d248f207d880e9f1655ab2491a1e0fb3);
#
#
#             var icon_5974952cb0c61ccf5159808200b4fb5b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor

# %% [markdown]
# It looks like our centers lie in the middle of the bay. This is due to the fact that SF has a city center and nearby cities also have a lot of tech companies. Both of these areas surround the San Francisco Bay.
#
# Lets split our analysis in two, the SF city center and southern nearby cities.
#
# First, lets get new GeoJsons and find out many companies are in each sub divison.

# %%
city_names = ["sf_center", "sf_south"]
sf_cities = load_cities(city_names)
sf_cities
# Out:
# {'Sf_Center': <POLYGON ((-122.419 37.883, -122.432 37.883, -122.445 37.881, -122.457 37.87...>,
#  'Sf_South': <POLYGON ((-122.406 37.569, -122.355 37.518, -122.3 37.486, -122.241 37.448,...>}

# %% [markdown]
# Let's create a new DF just for SF center and SF south

# %%
sf_center = final_data[final_data['city'] == "San_Francisco"]
sf_south = sf_center

# %% [markdown]
# From these new data sets we will asign new city names based on their location and our new disctintion.

# %%
sf_center = add_city_name(sf_center, sf_cities)
sf_south = add_city_name(sf_south, sf_cities)
sf_center = sf_center[sf_center["city"]=="Sf_Center"]
sf_center.sample(5)
# Out:
# /Users/kike/Documents/Personal/Educación/IronHack/Module 1/Week 4/project-III-geospatial-data/python_scripts/data_process.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'] = city_names
#              name      office description  office latitude  office longitude  \
# 3          GitHub                                37.775196       -122.419204
# 39      Pixelpipe      World Headquarters        37.764395       -122.401024
# 302       GoingOn  GoingOn Networks, Inc.        37.782263       -122.392142
# 386      AdParlor           San Francisco        37.788660       -122.401406
# 242  InnerRewards              West Coast        37.786910       -122.404403
#
#           city    type
# 3    Sf_Center    tech
# 39   Sf_Center    tech
# 302  Sf_Center    tech
# 386  Sf_Center  design
# 242  Sf_Center    tech

# %%
sf_south = sf_south[sf_south["city"]=="Sf_South"]
sf_south.sample(5)
# Out:
#           name     office description  office latitude  office longitude  \
# 188    ScaleMP                               37.322973       -122.038579
# 203    Relevad  Silicon Valley Office        37.559267       -122.302251
# 696  Fanminder           Headquarters        37.379249       -122.115127
# 80     iCharts            Main Office        37.384239       -122.012475
# 141   PLYmedia                               37.400821       -122.131383
#
#          city    type
# 188  Sf_South    tech
# 203  Sf_South  design
# 696  Sf_South  design
# 80   Sf_South    tech
# 141  Sf_South  design

# %% [markdown]
# Now lets find out the center for both categories and both cities and map them all. Lets start a fresh new map for this:

# %%
sf_map = sf_map(sf_center, sf_south)
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5b427bdff5fb99c090dbd1950c630f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5b427bdff5fb99c090dbd1950c630f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5b427bdff5fb99c090dbd1950c630f1 = L.map(
#                 &quot;map_d5b427bdff5fb99c090dbd1950c630f1&quot;,
#                 {
#                     center: [37.6, -122.15],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87d321d98aa063967fa14b67f0920f10 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d5b427bdff5fb99c090dbd1950c630f1);
#
#
#             var feature_group_13e14c880e1b152e57a525a121cae6b2 = L.featureGroup(
#                 {}
#             ).addTo(map_d5b427bdff5fb99c090dbd1950c630f1);
#
#
#             var marker_3a36f4869c314fb3b09c8d7055bbc358 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_13e14c880e1b152e57a525a121cae6b2);
#
#
#             var icon_baddb8237b46b7d5b2481b0d415d635f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3a36f4869c314fb3b09c8d7055bbc358.setIcon(icon_baddb8237b46b7d5b2481b0d415d635f);
#
#
#             marker_3a36f4869c314fb3b09c8d7055bbc358.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_406313c75dfd5022b0d9889ac9c696f5 = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_13e14c880e1b152e57a525a121cae6b2);
#
#
#             var icon_499db5923928932e379b564fcf90d057 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_406313c75dfd5022b0d9889ac9c696f5.setIcon(icon_499db5923928932e379b564fcf90d057);
#
#
#             marker_406313c75dfd5022b0d9889ac9c696f5.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9176abda3bf8923de29d6eae1ede1dbd = L.marker(
#                 [37.758352, -122.398379],
#                 {}
#             ).addTo(feature_group_13e14c880e1b152e57a525a121cae6b2);
#
#
#             var icon_a85c6f720906a4deaf8938d3207e04c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9176abda3bf8923de29d6eae1ede1dbd.setIcon(icon_a85c6f720906a4deaf8938d3207e04c7);
#
#
#             marker_9176abda3bf8923de29d6eae1ede1dbd.bindTooltip(
#                 `&lt;div&gt;
#                      Open Places
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3a2bb904cdf4c140cc787462ba307e7e = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_13e14c880e1b152e57a525a121cae6b2);
#
#
#             var icon_5f6606239d5c403c0987796afd989c91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3a2bb904cdf4c140cc787462ba307e7e.setIcon(icon_5f6606239d5c403c0987796afd989c91);
#
#
#             marker_3a2bb904cdf4c140cc787462ba307e7e.bindTooltip(
#                 `&lt;div&gt;
#                      Stitcher
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e9be709a8ad6bfc979347c0c4f8ba5c = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_13e14c880e1b152e57a525a121cae6b2);
#
#
#             var icon_5b7ff82d42d2cf4bfb1909ce9767c37d = L.AwesomeMarkers.icon(

# %% [markdown]
# Great! Looks like both sectors have mean coordinates pretty close to each other.
# Let's find out which one has more companies:

# %%
sf = pd.concat([sf_center, sf_south], axis=0)
sf.groupby(["city","type"])["name"].agg("count").reset_index()
# Out:
#         city    type  name
# 0  Sf_Center  design    67
# 1  Sf_Center    tech    26
# 2   Sf_South  design    45
# 3   Sf_South    tech    25

# %% [markdown]
# Since the San Francisco City Center has more companies and they are all closer together, let's focus on this area for our location.
#
# Now we will find out the mean coordinates between the centers of both sectors. This will define the most desireable location for our office.

# %%
sf_center_tech_mean = mean_coordinates(sf_center[(sf_center["type"] == 'tech')])
sf_center_design_mean = mean_coordinates(sf_center[(sf_center["type"] == 'design')])

office_location = mean_coordinates_raw([sf_center_tech_mean,sf_center_design_mean])
office_location
# Out:
# [37.7824, -122.4039]

# %% [markdown]
# Great! Now that we have our desired location lets see how it sits on the map in relation to our other companies

# %%
sf_map_2 = sf_map_2(sf_center, office_location)
sf_map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a075acff7beb31ddd545b0add1a8d65e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a075acff7beb31ddd545b0add1a8d65e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a075acff7beb31ddd545b0add1a8d65e = L.map(
#                 &quot;map_a075acff7beb31ddd545b0add1a8d65e&quot;,
#                 {
#                     center: [37.767, -122.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66d9f6fd5887408b04ada31128517e3d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a075acff7beb31ddd545b0add1a8d65e);
#
#
#             var feature_group_1015f96c4bc34e051c18a70c985b09b1 = L.featureGroup(
#                 {}
#             ).addTo(map_a075acff7beb31ddd545b0add1a8d65e);
#
#
#             var marker_dcdbe7faaa7a897c61a701602c9006a1 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_1015f96c4bc34e051c18a70c985b09b1);
#
#
#             var icon_2bfab4ad2a7ebf3294f156aefe300fb3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dcdbe7faaa7a897c61a701602c9006a1.setIcon(icon_2bfab4ad2a7ebf3294f156aefe300fb3);
#
#
#             marker_dcdbe7faaa7a897c61a701602c9006a1.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e020c96cc4672ef60024c8ba0181260d = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_1015f96c4bc34e051c18a70c985b09b1);
#
#
#             var icon_9633d5e161cba9e7da5bb8d3716db9db = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e020c96cc4672ef60024c8ba0181260d.setIcon(icon_9633d5e161cba9e7da5bb8d3716db9db);
#
#
#             marker_e020c96cc4672ef60024c8ba0181260d.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3c3cf8de3a6d5c21ff4c433b64aa866f = L.marker(
#                 [37.758352, -122.398379],
#                 {}
#             ).addTo(feature_group_1015f96c4bc34e051c18a70c985b09b1);
#
#
#             var icon_f09344a2d6a1c6c30816a00016f25048 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3c3cf8de3a6d5c21ff4c433b64aa866f.setIcon(icon_f09344a2d6a1c6c30816a00016f25048);
#
#
#             marker_3c3cf8de3a6d5c21ff4c433b64aa866f.bindTooltip(
#                 `&lt;div&gt;
#                      Open Places
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_55b6a580e1d57152d544c5e44f03aeb3 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_1015f96c4bc34e051c18a70c985b09b1);
#
#
#             var icon_355e49e77c58ae26f470c622720902e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_55b6a580e1d57152d544c5e44f03aeb3.setIcon(icon_355e49e77c58ae26f470c622720902e4);
#
#
#             marker_55b6a580e1d57152d544c5e44f03aeb3.bindTooltip(
#                 `&lt;div&gt;
#                      Stitcher
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8f5d9b79d82ec6c75773202f96958e50 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_1015f96c4bc34e051c18a70c985b09b1);
#
#
#             var icon_26e8315ab022b23cab31191a20ca988e = L.AwesomeMarkers.icon(

# %% [markdown]
# Awesome! Looks like our office is right in the center of San Francisco.
#
# Now lets take into consideration the rest of the requirements:
# 1. Near airports
# 2. Near schools
# 3. Near starbucks
# 4. Near restaurants with vegan options
# 5. Near a basketball court
# 6. Near a pet grooming services for the company dog
#
# For all of these requirements we will use the Foursquare API. To avoid querying it excesively, all queries were done once and the data recovered from them saved in a DataFrame. We will import this data from an exported CSV. The detailed querying process can be seen in the foursquare.py Python Script that produced this file.
