# %% [markdown]
# # Office location selection
#
# For this project we will determine the best posible location for an office that satisfies all the requirements stated in the project description. Here's a summary:
#
# 1. It must be near tech startups that have raised more than 1MM USD.
# 2. It must be near other companies that do design.
# 3. It must be near schools since 1/3 of employees have at least 1 child.
# 4. It must be near an airport.
# 5. It should be near a Starbucks.
# 6. It should have nearby restaurants with vegan options.
# 7. It should have a basketball court within 10 Km.
# 8. It must have a pet grooming service nearby for the company dog.
#
# For this, we will use the companies Mongo DB provided by crunchbase.
#
# First, lets run our python script that defines the functions we will work with:

# %%
# %run -i 'python_scripts/mongo_connection.py'

# %% [markdown]
# Now lets establish the connection to our Mongo Database. For this we will use a function specified in the mongo_connection.py script.

# %%
c = connect_mongo("ironhack","companies")
c
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'companies')

# %% [markdown]
# Our connection was succesful! Now lets query our companies collection for tech startups and design companies. Again we will use functions defined for these tasks in the mongo_connection.py script since the queries are quite long.

# %%
tech = get_tech_startups(1000000,2008)
# Out:
# Query returned  274  companies.

# %%
design = get_design_companies()
# Out:
# Query returned  965  companies.

# %% [markdown]
# Now that we have our company data, lets process it to eliminate those without coordinates and transform these lists into DataFrames. For this we will use pre-defined functions in our data_process script, lets run it:

# %%
# %run -i 'python_scripts/data_process.py'

# %%
tech_data = get_offices_location(tech)
# Out:
# Received data for  333  companies.
#  202  companies with full location information left.

# %%
design_data = get_offices_location(design)
# Out:
# Received data for  1094  companies.
#  708  companies with full location information left.

# %% [markdown]
# Now that we have data for all tech and design companies that fit our criteria, lets make a heatmap of their location to see which cities have more of both. For this we will load our mappying script since it has functions that will help us map this information.

# %%
# %run -i 'python_scripts/mapping.py'

# %%
heat_map = map_heatmap(tech_data, design_data)
heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49dd5cb33cc273d3ecd0a431d78fe9b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49dd5cb33cc273d3ecd0a431d78fe9b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49dd5cb33cc273d3ecd0a431d78fe9b7 = L.map(
#                 &quot;map_49dd5cb33cc273d3ecd0a431d78fe9b7&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f91274104730fc8bab23d1f93a652421 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49dd5cb33cc273d3ecd0a431d78fe9b7);
#
#
#             var feature_group_57529c256e7fc99e7b326d935cfdaf54 = L.featureGroup(
#                 {}
#             ).addTo(map_49dd5cb33cc273d3ecd0a431d78fe9b7);
#
#
#             var heat_map_d58131fe3b29fcf13eb9ce63cd0dfdd5 = L.heatLayer(
#                 [[34.005914, -118.488129], [40.7481039, -74.0353787], [40.744618, -73.987764], [42.3756409, -72.5196907], [42.2968126, -71.3876282], [52.132633, 5.291266], [34.0497638, -118.2474287], [34.007112, -118.489748], [39.749671, -104.9998449], [37.781265, -122.393229], [37.7893215, -122.4013624], [32.88945, -117.166929], [42.3624253, -71.116031], [38.6501668, -90.2598684], [40.7272544, -74.0057152], [37.39458, -121.928393], [29.7847641, -82.4768036], [45.3774456, -122.7569561], [34.052187, -118.243425], [47.6220245, -122.3350847], [40.532969, -80.010645], [38.94794, -77.347961], [40.7408042, -74.00717], [37.5758867, -122.3277578], [42.318138, -71.24756], [41.4063346, 2.1920231], [39.749671, -104.9998449], [37.270518, -121.955879], [34.005914, -118.488129], [37.7870923, -122.3999719], [38.257035, -85.717393], [37.78691, -122.404403], [40.741594, -73.990468], [37.504764, -122.259568], [26.2032036, -80.1510951], [12.9349604, 77.6136847], [32.0554, 34.7595], [37.7905538, -122.4041485], [39.9443552, -75.1257381], [40.756054, -73.986951], [51.517356, -0.1037742], [40.0230047, -105.2532841], [38.88521, -76.998641], [34.168955, -118.575293], [37.4484914, -122.1802812], [32.0554, 34.7595], [-23.5489433, -46.6388182], [40.775309, -73.983656], [40.757929, -73.985506], [40.018145, -105.278109], [34.111471, -118.174878], [42.3647559, -71.1032591], [40.74034, -74.00721], [39.9052263, -86.0547016], [48.868478, 2.339843], [21.303049, -157.78907], [37.51821, -122.044025], [37.41924, -122.208414], [37.785271, -122.397582], [51.5224267, -0.1046546], [43.644678, -79.567221], [46.2121463, 6.1503245], [37.523194, -122.259179], [32.89892, -117.242961], [32.0554, 34.7595], [38.906867, -77.042322], [40.4455155, -3.7061764], [40.7078343, -74.0136605], [51.5499708, -0.1815999], [28.5821195, 77.3266991], [30.327779, -97.669955], [42.603532, -83.16134], [37.782263, -122.392142], [40.750597, -73.985273], [37.7871306, -122.4041075], [52.143886, -106.6634565], [37.269175, -119.306607], [47.603364, -122.333359], [49.2824551, -123.109217], [30.310978, -81.657707], [38.960381, -77.084811], [40.4225487, -3.6830316], [51.5480857, 0.6553168], [38.916336, -77.230488], [45.546481, -122.9021288], [53.544711, -113.515769], [48.8952712, 2.4476331], [37.5252461, -121.9178417], [48.8566667, 2.3509871], [37.775196, -122.419204], [37.7900992, -122.4021988], [42.392628, -71.151216], [52.5308516, 13.3842605], [37.788796, -122.40971], [29.9739941, -90.0822015], [47.6103008, -122.3399782], [40.026, -105.259041], [47.676762, -122.2049192], [40.740231, -73.985433], [37.5646055, -122.3229235], [44.8743952, -0.5754294], [37.804619, -122.371203], [37.503147, -122.211435], [37.384239, -122.012475], [45.5251, -122.8097], [51.51819, -0.208979], [37.4239496, -122.1011815], [41.3279176, -73.2435522], [41.792265, 1.996567], [32.037363, 34.8003705], [47.6257402, -122.3581623], [37.78691, -122.404403], [40.741594, -73.990468], [21.303049, -157.78907], [32.037363, 34.8003705], [41.4225841, -81.3857728], [34.1012181, -118.325739], [38.6501668, -90.2598684], [40.7272544, -74.0057152], [40.438423, -80.001933], [52.3657578, 4.8928722], [34.153588, -118.422495], [37.775196, -122.419204], [34.0137151, -118.4660597], [33.8171, -111.9035], [40.739867, -73.990024], [48.8318497, 2.3389864], [37.7870923, -122.3999719], [28.7164018, 77.1765029], [37.4104762, -122.0185959], [49.2851733, -123.0952381], [45.546481, -122.9021288], [37.5561712, -122.0780632], [12.971606, 77.594376], [40.7185614, -73.998662], [52.143886, -106.6634565], [37.566879, -122.323895], [40.7481039, -74.0353787], [40.775309, -73.983656], [51.5196135, -0.1020265], [37.4484914, -122.1802812], [37.8017938, -122.4043215], [37.384239, -12

# %%
heat_map.save("data/maps/heat_map.html")

# %% [markdown]
# Browsing this heatmap, it looks like our offices should be either in San francisco, Los Angeles, New york, Miami, Paris or Manchester. Let's get GeoJsons for these cities.
#
# Rather than looking for defined poligons with the borders of these cities, I created GeoJson files of circles encompassing these cities and their surrounding area. I made them wide enough so that they covered nearby towns that also have important amounts of companies.

# %%
city_names = ["san_francisco", "los_angeles", "new_york", "miami", "paris", "manchester"]
cities = load_cities(city_names)
cities
# Out:
# {'San_Francisco': <POLYGON ((-122.241 38.23, -122.312 38.227, -122.383 38.219, -122.452 38.205...>,
#  'Los_Angeles': <POLYGON ((-118.113 34.81, -118.207 34.807, -118.3 34.795, -118.392 34.776, ...>,
#  'New_York': <POLYGON ((-73.977 41.103, -74.021 41.102, -74.064 41.097, -74.107 41.089, -...>,
#  'Miami': <POLYGON ((-80.271 26.121, -80.305 26.12, -80.338 26.115, -80.371 26.108, -8...>,
#  'Paris': <POLYGON ((2.354 49.066, 2.322 49.065, 2.292 49.062, 2.261 49.057, 2.232 49....>,
#  'Manchester': <POLYGON ((-2.244 53.593, -2.263 53.593, -2.282 53.591, -2.3 53.589, -2.318 ...>}

# %% [markdown]
# Now that we have our GeoJsons loaded, lets add the city name to our DataFrames, based on these GeoJsons.
#
# This stepp will check for every office in our Data Frame, if that location is in one of the cirlces defined by the GeoJsons, it will add that city name to our DataFrame.

# %%
tech_data = add_city_name(tech_data, cities)
# We will also be adding a "tech" identifier in a new column called "type". This will be useful in a future step, where we will consolidate all of our data in a single DataFrame.
tech_data["type"] = "tech"
tech_data.head()
# Out:
#                      name      office description  office latitude  \
# 1        Geodelic Systems             Geodelic HQ        34.005914
# 2               Integrate           Scottsdale HQ        40.748104
# 7                   Yipit                      HQ        40.744618
# 8                Tinychat             Home Office        42.375641
# 9  OutSmart Power Systems  OutSmart Power Systems        42.296813
#
#    office longitude         city  type
# 1       -118.488129  Los_Angeles  tech
# 2        -74.035379     New_York  tech
# 7        -73.987764     New_York  tech
# 8        -72.519691         None  tech
# 9        -71.387628         None  tech

# %% [markdown]
# Now we will do the same thing for our desgin companies

# %%
design_data = add_city_name(design_data, cities)
design_data["type"] = "design"
design_data.head()
# Out:
#          name  office description  office latitude  office longitude  \
# 0  Technorati                            37.779558       -122.393041
# 1     AddThis       HQ - Virginia        38.926172        -77.245195
# 2     AddThis     New York Office        40.724604        -73.996876
# 3     AddThis  Los Angeles Office        34.026302       -118.380954
# 6     AddThis     Michigan Office        42.557958        -83.167884
#
#             city    type
# 0  San_Francisco  design
# 1           None  design
# 2       New_York  design
# 3    Los_Angeles  design
# 6           None  design

# %% [markdown]
# Now lets join these DataFrames and find out the top cities with more companies.

# %%
full_data = pd.concat([tech_data, design_data], axis=0)
top_cities = full_data.groupby(['city', 'type'])['name'].agg('count').reset_index()
top_cities
# Out:
#             city    type  name
# 0    Los_Angeles  design    46
# 1    Los_Angeles    tech    14
# 2     Manchester  design     3
# 3          Miami  design     7
# 4       New_York  design    80
# 5       New_York    tech    22
# 6          Paris  design    10
# 7          Paris    tech     4
# 8  San_Francisco  design   123
# 9  San_Francisco    tech    58

# %% [markdown]
# Looks like our top 3 cities with more tech and design companies are San Francisco, New York and Los Angeles. Lets drop the rest:

# %%
top_cities = top_cities.drop([2,3,6,7])
top_cities
# Out:
#             city    type  name
# 0    Los_Angeles  design    46
# 1    Los_Angeles    tech    14
# 4       New_York  design    80
# 5       New_York    tech    22
# 8  San_Francisco  design   123
# 9  San_Francisco    tech    58

# %% [markdown]
# Having narrowed down our search to these 3 cities lets map them.
# First, lets consolidate our data:

# %%
final_data = full_data[full_data['city'].isin(['Los_Angeles', 'New_York', 'San_Francisco'])]
final_data.head()
# Out:
#                 name office description  office latitude  office longitude  \
# 1   Geodelic Systems        Geodelic HQ        34.005914       -118.488129
# 2          Integrate      Scottsdale HQ        40.748104        -74.035379
# 7              Yipit                 HQ        40.744618        -73.987764
# 11             Klout                           34.049764       -118.247429
# 12            Tongal       Headquarters        34.007112       -118.489748
#
#            city  type
# 1   Los_Angeles  tech
# 2      New_York  tech
# 7      New_York  tech
# 11  Los_Angeles  tech
# 12  Los_Angeles  tech

# %% [markdown]
# Now lets map our 3 cities:

# %%
top_3_map = top_3_map(final_data)
top_3_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b27ee5a6cb648cd7f167a75dbdba1c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b27ee5a6cb648cd7f167a75dbdba1c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b27ee5a6cb648cd7f167a75dbdba1c9 = L.map(
#                 &quot;map_6b27ee5a6cb648cd7f167a75dbdba1c9&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a03b48d8a8b6ee7ca5ab5f33b7947b37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b27ee5a6cb648cd7f167a75dbdba1c9);
#
#
#             var feature_group_4cc2871c4bbafb0c8df4cf6906e7361c = L.featureGroup(
#                 {}
#             ).addTo(map_6b27ee5a6cb648cd7f167a75dbdba1c9);
#
#
#             var marker_0bee50e4e2811e8f37e33f85bafa402a = L.marker(
#                 [34.005914, -118.488129],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_302abdcef6d270a6560a54214aacbbe3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0bee50e4e2811e8f37e33f85bafa402a.setIcon(icon_302abdcef6d270a6560a54214aacbbe3);
#
#
#             marker_0bee50e4e2811e8f37e33f85bafa402a.bindTooltip(
#                 `&lt;div&gt;
#                      Geodelic Systems
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a645c73c9445b3a70ee76bd1be9ba0bc = L.marker(
#                 [40.7481039, -74.0353787],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_231e8f63da4aa06f57096e2c734b7436 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a645c73c9445b3a70ee76bd1be9ba0bc.setIcon(icon_231e8f63da4aa06f57096e2c734b7436);
#
#
#             marker_a645c73c9445b3a70ee76bd1be9ba0bc.bindTooltip(
#                 `&lt;div&gt;
#                      Integrate
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_09b967a41a4cb9efab8d425c1bafdd53 = L.marker(
#                 [40.744618, -73.987764],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_be8b6e35883bb354beb2e50a14c753a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_09b967a41a4cb9efab8d425c1bafdd53.setIcon(icon_be8b6e35883bb354beb2e50a14c753a2);
#
#
#             marker_09b967a41a4cb9efab8d425c1bafdd53.bindTooltip(
#                 `&lt;div&gt;
#                      Yipit
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5ab459683c22cb499f3d02d21cfbe64c = L.marker(
#                 [34.0497638, -118.2474287],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_b7446a29dd54756f7fe6ca067b061ad4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5ab459683c22cb499f3d02d21cfbe64c.setIcon(icon_b7446a29dd54756f7fe6ca067b061ad4);
#
#
#             marker_5ab459683c22cb499f3d02d21cfbe64c.bindTooltip(
#                 `&lt;div&gt;
#                      Klout
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_735c751a790bddcdb6dae14b270c0ed7 = L.marker(
#                 [34.007112, -118.489748],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_e149b597224cfe921248674844fa2354 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quo

# %% [markdown]
# Browsing this map, lets focus on San Francisco since it is the city with most companies.

# %%
top_3_map.fit_bounds([[37.8,-122.4],[37.5,-122.1]], padding=(4,4))
top_3_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b27ee5a6cb648cd7f167a75dbdba1c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b27ee5a6cb648cd7f167a75dbdba1c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b27ee5a6cb648cd7f167a75dbdba1c9 = L.map(
#                 &quot;map_6b27ee5a6cb648cd7f167a75dbdba1c9&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a03b48d8a8b6ee7ca5ab5f33b7947b37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b27ee5a6cb648cd7f167a75dbdba1c9);
#
#
#             var feature_group_4cc2871c4bbafb0c8df4cf6906e7361c = L.featureGroup(
#                 {}
#             ).addTo(map_6b27ee5a6cb648cd7f167a75dbdba1c9);
#
#
#             var marker_0bee50e4e2811e8f37e33f85bafa402a = L.marker(
#                 [34.005914, -118.488129],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_302abdcef6d270a6560a54214aacbbe3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0bee50e4e2811e8f37e33f85bafa402a.setIcon(icon_302abdcef6d270a6560a54214aacbbe3);
#
#
#             marker_0bee50e4e2811e8f37e33f85bafa402a.bindTooltip(
#                 `&lt;div&gt;
#                      Geodelic Systems
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a645c73c9445b3a70ee76bd1be9ba0bc = L.marker(
#                 [40.7481039, -74.0353787],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_231e8f63da4aa06f57096e2c734b7436 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a645c73c9445b3a70ee76bd1be9ba0bc.setIcon(icon_231e8f63da4aa06f57096e2c734b7436);
#
#
#             marker_a645c73c9445b3a70ee76bd1be9ba0bc.bindTooltip(
#                 `&lt;div&gt;
#                      Integrate
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_09b967a41a4cb9efab8d425c1bafdd53 = L.marker(
#                 [40.744618, -73.987764],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_be8b6e35883bb354beb2e50a14c753a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_09b967a41a4cb9efab8d425c1bafdd53.setIcon(icon_be8b6e35883bb354beb2e50a14c753a2);
#
#
#             marker_09b967a41a4cb9efab8d425c1bafdd53.bindTooltip(
#                 `&lt;div&gt;
#                      Yipit
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5ab459683c22cb499f3d02d21cfbe64c = L.marker(
#                 [34.0497638, -118.2474287],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_b7446a29dd54756f7fe6ca067b061ad4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5ab459683c22cb499f3d02d21cfbe64c.setIcon(icon_b7446a29dd54756f7fe6ca067b061ad4);
#
#
#             marker_5ab459683c22cb499f3d02d21cfbe64c.bindTooltip(
#                 `&lt;div&gt;
#                      Klout
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_735c751a790bddcdb6dae14b270c0ed7 = L.marker(
#                 [34.007112, -118.489748],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_e149b597224cfe921248674844fa2354 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quo

# %% [markdown]
# Let's find out the point that is closest to all of our companies. I'll calculate the mean coordinate for our tech companies and for our design companies separately and add this to our map:

# %%
sf_middle_tech = mean_coordinates(final_data[(final_data["city"] == 'San_Francisco')&(final_data["type"] == 'tech')])
sf_middle_design = mean_coordinates(final_data[(final_data["city"] == 'San_Francisco')&(final_data["type"] == 'design')])

add_marker("sf_tech_center","orange","computer",sf_middle_tech,top_3_map)
add_marker("sf_design_center","red","fa-shopping-bag",sf_middle_design,top_3_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b27ee5a6cb648cd7f167a75dbdba1c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b27ee5a6cb648cd7f167a75dbdba1c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b27ee5a6cb648cd7f167a75dbdba1c9 = L.map(
#                 &quot;map_6b27ee5a6cb648cd7f167a75dbdba1c9&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a03b48d8a8b6ee7ca5ab5f33b7947b37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b27ee5a6cb648cd7f167a75dbdba1c9);
#
#
#             var feature_group_4cc2871c4bbafb0c8df4cf6906e7361c = L.featureGroup(
#                 {}
#             ).addTo(map_6b27ee5a6cb648cd7f167a75dbdba1c9);
#
#
#             var marker_0bee50e4e2811e8f37e33f85bafa402a = L.marker(
#                 [34.005914, -118.488129],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_302abdcef6d270a6560a54214aacbbe3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0bee50e4e2811e8f37e33f85bafa402a.setIcon(icon_302abdcef6d270a6560a54214aacbbe3);
#
#
#             marker_0bee50e4e2811e8f37e33f85bafa402a.bindTooltip(
#                 `&lt;div&gt;
#                      Geodelic Systems
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a645c73c9445b3a70ee76bd1be9ba0bc = L.marker(
#                 [40.7481039, -74.0353787],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_231e8f63da4aa06f57096e2c734b7436 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a645c73c9445b3a70ee76bd1be9ba0bc.setIcon(icon_231e8f63da4aa06f57096e2c734b7436);
#
#
#             marker_a645c73c9445b3a70ee76bd1be9ba0bc.bindTooltip(
#                 `&lt;div&gt;
#                      Integrate
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_09b967a41a4cb9efab8d425c1bafdd53 = L.marker(
#                 [40.744618, -73.987764],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_be8b6e35883bb354beb2e50a14c753a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_09b967a41a4cb9efab8d425c1bafdd53.setIcon(icon_be8b6e35883bb354beb2e50a14c753a2);
#
#
#             marker_09b967a41a4cb9efab8d425c1bafdd53.bindTooltip(
#                 `&lt;div&gt;
#                      Yipit
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5ab459683c22cb499f3d02d21cfbe64c = L.marker(
#                 [34.0497638, -118.2474287],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_b7446a29dd54756f7fe6ca067b061ad4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5ab459683c22cb499f3d02d21cfbe64c.setIcon(icon_b7446a29dd54756f7fe6ca067b061ad4);
#
#
#             marker_5ab459683c22cb499f3d02d21cfbe64c.bindTooltip(
#                 `&lt;div&gt;
#                      Klout
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_735c751a790bddcdb6dae14b270c0ed7 = L.marker(
#                 [34.007112, -118.489748],
#                 {}
#             ).addTo(feature_group_4cc2871c4bbafb0c8df4cf6906e7361c);
#
#
#             var icon_e149b597224cfe921248674844fa2354 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quo

# %% [markdown]
# It looks like our centers lie in the middle of the bay. This is due to the fact that SF has a city center and nearby cities also have a lot of tech companies. Both of these areas surround the San Francisco Bay.
#
# Lets split our analysis in two, the SF city center and southern nearby cities.
#
# First, lets get new GeoJsons and find out many companies are in each sub divison.

# %%
city_names = ["sf_center", "sf_south"]
sf_cities = load_cities(city_names)
sf_cities
# Out:
# {'Sf_Center': <POLYGON ((-122.419 37.883, -122.432 37.883, -122.445 37.881, -122.457 37.87...>,
#  'Sf_South': <POLYGON ((-122.406 37.569, -122.355 37.518, -122.3 37.486, -122.241 37.448,...>}

# %% [markdown]
# Let's create a new DF just for SF center and SF south

# %%
sf_center = final_data[final_data['city'] == "San_Francisco"]
sf_south = sf_center

# %% [markdown]
# From these new data sets we will asign new city names based on their location and our new disctintion.

# %%
sf_center = add_city_name(sf_center, sf_cities)
sf_south = add_city_name(sf_south, sf_cities)
sf_center = sf_center[sf_center["city"]=="Sf_Center"]
sf_center.sample(5)
# Out:
# /Users/kike/Documents/Personal/Educación/IronHack/Module 1/Week 4/project-III-geospatial-data/python_scripts/data_process.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'] = city_names
#             name         office description  office latitude  \
# 184       Flurry       Flurry San Francisco        37.783046
# 252       PicApp                                   37.794020
# 49   Adknowledge  Adknowledge San Francisco        37.788660
# 294     Fotomoto                Main Office        37.779501
# 153         KODA              San Francisco        37.788796
#
#      office longitude       city    type
# 184       -122.394067  Sf_Center  design
# 252       -122.403124  Sf_Center    tech
# 49        -122.401406  Sf_Center  design
# 294       -122.394871  Sf_Center    tech
# 153       -122.409710  Sf_Center    tech

# %%
sf_south = sf_south[sf_south["city"]=="Sf_South"]
sf_south.sample(5)
# Out:
#                    name     office description  office latitude  \
# 42             VisualOn           Headquarters        37.270518
# 872            Luminate                               37.399833
# 304  Efficient Frontier           Headquarters        37.404973
# 203             Relevad  Silicon Valley Office        37.559267
# 309           Gridstore              Gridstore        37.418907
#
#      office longitude      city    type
# 42        -121.955879  Sf_South    tech
# 872       -122.046545  Sf_South  design
# 304       -122.032353  Sf_South  design
# 203       -122.302251  Sf_South  design
# 309       -122.088429  Sf_South    tech

# %% [markdown]
# Now lets find out the center for both categories and both cities and map them all. Lets start a fresh new map for this:

# %%
sf_map = sf_map(sf_center, sf_south)
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d063b0a2cf98ef516e212fe6525a07eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d063b0a2cf98ef516e212fe6525a07eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d063b0a2cf98ef516e212fe6525a07eb = L.map(
#                 &quot;map_d063b0a2cf98ef516e212fe6525a07eb&quot;,
#                 {
#                     center: [37.6, -122.15],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56edba31267e87d88d7fa76453d8d467 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d063b0a2cf98ef516e212fe6525a07eb);
#
#
#             var feature_group_b8bb4084ca24e9cd1aeaa508e967a1d7 = L.featureGroup(
#                 {}
#             ).addTo(map_d063b0a2cf98ef516e212fe6525a07eb);
#
#
#             var marker_36589fd0bdd5441879adb82597a8daff = L.marker(
#                 [37.781265, -122.393229],
#                 {}
#             ).addTo(feature_group_b8bb4084ca24e9cd1aeaa508e967a1d7);
#
#
#             var icon_2b241b972eedeac889c464a7667a2fb0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_36589fd0bdd5441879adb82597a8daff.setIcon(icon_2b241b972eedeac889c464a7667a2fb0);
#
#
#             marker_36589fd0bdd5441879adb82597a8daff.bindTooltip(
#                 `&lt;div&gt;
#                      Crunchyroll
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a78e9e60ccffa5038db15a403f114acc = L.marker(
#                 [37.7893215, -122.4013624],
#                 {}
#             ).addTo(feature_group_b8bb4084ca24e9cd1aeaa508e967a1d7);
#
#
#             var icon_e70b173a353f3973d16c52ad50140c6a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a78e9e60ccffa5038db15a403f114acc.setIcon(icon_e70b173a353f3973d16c52ad50140c6a);
#
#
#             marker_a78e9e60ccffa5038db15a403f114acc.bindTooltip(
#                 `&lt;div&gt;
#                      Serious Business
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b34578052eaf752dc8af72a463087fb5 = L.marker(
#                 [37.7870923, -122.3999719],
#                 {}
#             ).addTo(feature_group_b8bb4084ca24e9cd1aeaa508e967a1d7);
#
#
#             var icon_e1f122ab6ecd03acabf50c0454a31606 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b34578052eaf752dc8af72a463087fb5.setIcon(icon_e1f122ab6ecd03acabf50c0454a31606);
#
#
#             marker_b34578052eaf752dc8af72a463087fb5.bindTooltip(
#                 `&lt;div&gt;
#                      Lolapps
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_af2a22db472799cfcf1d4f2386657c57 = L.marker(
#                 [37.78691, -122.404403],
#                 {}
#             ).addTo(feature_group_b8bb4084ca24e9cd1aeaa508e967a1d7);
#
#
#             var icon_b3851d05f63892d316de9206fb4486ae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_af2a22db472799cfcf1d4f2386657c57.setIcon(icon_b3851d05f63892d316de9206fb4486ae);
#
#
#             marker_af2a22db472799cfcf1d4f2386657c57.bindTooltip(
#                 `&lt;div&gt;
#                      InnerRewards
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_37f7b4c313a42de6e80dc1cb47a6aecb = L.marker(
#                 [37.7905538, -122.4041485],
#                 {}
#             ).addTo(feature_group_b8bb4084ca24e9cd1aeaa508e967a1d7);
#
#
#             var icon_f6588f1e6f4b92eb67bcb7e2312906ed = L.AwesomeMarker

# %% [markdown]
# Great! Looks like both sectors have mean coordinates pretty close to each other.
# Let's find out which one has more companies:

# %%
sf = pd.concat([sf_center, sf_south], axis=0)
sf.groupby(["city","type"])["name"].agg("count").reset_index()
# Out:
#         city    type  name
# 0  Sf_Center  design    67
# 1  Sf_Center    tech    26
# 2   Sf_South  design    45
# 3   Sf_South    tech    25

# %% [markdown]
# Since the San Francisco City Center has more companies and they are all closer together, let's focus on this area for our location.
#
# Now we will find out the mean coordinates between the centers of both sectors. This will define the most desireable location for our office.

# %%
sf_center_tech_mean = mean_coordinates(sf_center[(sf_center["type"] == 'tech')])
sf_center_design_mean = mean_coordinates(sf_center[(sf_center["type"] == 'design')])

office_location = mean_coordinates_raw([sf_center_tech_mean,sf_center_design_mean])
office_location
# Out:
# [37.7824, -122.4039]

# %% [markdown]
# Great! Now that we have our desired location lets see how it sits on the map in relation to our other companies

# %%
sf_map_2 = sf_map_2(sf_center, office_location)
sf_map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa319ad7ab7e7b0ca988f4f06aa18da4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa319ad7ab7e7b0ca988f4f06aa18da4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa319ad7ab7e7b0ca988f4f06aa18da4 = L.map(
#                 &quot;map_aa319ad7ab7e7b0ca988f4f06aa18da4&quot;,
#                 {
#                     center: [37.767, -122.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90ad9668c76834bc645dbb54251eac62 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa319ad7ab7e7b0ca988f4f06aa18da4);
#
#
#             var feature_group_00d6afcecbc77123044e0dbd2443f279 = L.featureGroup(
#                 {}
#             ).addTo(map_aa319ad7ab7e7b0ca988f4f06aa18da4);
#
#
#             var marker_1b2ce541422f93b85e4201bdeab3b5ea = L.marker(
#                 [37.781265, -122.393229],
#                 {}
#             ).addTo(feature_group_00d6afcecbc77123044e0dbd2443f279);
#
#
#             var icon_e1a8443c9354a273e5357ff352d862d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1b2ce541422f93b85e4201bdeab3b5ea.setIcon(icon_e1a8443c9354a273e5357ff352d862d0);
#
#
#             marker_1b2ce541422f93b85e4201bdeab3b5ea.bindTooltip(
#                 `&lt;div&gt;
#                      Crunchyroll
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cde37c1b84ac64d598b4980a5d81ae38 = L.marker(
#                 [37.7893215, -122.4013624],
#                 {}
#             ).addTo(feature_group_00d6afcecbc77123044e0dbd2443f279);
#
#
#             var icon_eadbcbe42d7636151bd385133f72497a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cde37c1b84ac64d598b4980a5d81ae38.setIcon(icon_eadbcbe42d7636151bd385133f72497a);
#
#
#             marker_cde37c1b84ac64d598b4980a5d81ae38.bindTooltip(
#                 `&lt;div&gt;
#                      Serious Business
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8c43e209f09347f6d4092355499dc177 = L.marker(
#                 [37.7870923, -122.3999719],
#                 {}
#             ).addTo(feature_group_00d6afcecbc77123044e0dbd2443f279);
#
#
#             var icon_0ab489b9ecb3d43838cbcf56105fa8a4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8c43e209f09347f6d4092355499dc177.setIcon(icon_0ab489b9ecb3d43838cbcf56105fa8a4);
#
#
#             marker_8c43e209f09347f6d4092355499dc177.bindTooltip(
#                 `&lt;div&gt;
#                      Lolapps
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b20b1c7811586197e32ebecc548c8bed = L.marker(
#                 [37.78691, -122.404403],
#                 {}
#             ).addTo(feature_group_00d6afcecbc77123044e0dbd2443f279);
#
#
#             var icon_88108cb4b1958375cd3f7a32967f4ecf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b20b1c7811586197e32ebecc548c8bed.setIcon(icon_88108cb4b1958375cd3f7a32967f4ecf);
#
#
#             marker_b20b1c7811586197e32ebecc548c8bed.bindTooltip(
#                 `&lt;div&gt;
#                      InnerRewards
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_13d6412202287a6064d70fff25e8fc08 = L.marker(
#                 [37.7905538, -122.4041485],
#                 {}
#             ).addTo(feature_group_00d6afcecbc77123044e0dbd2443f279);
#
#
#             var icon_122f4716fea0594876fc20cf4b659d3e = L.AwesomeMarke

# %% [markdown]
# Awesome! Looks like our office is right in the center of San Francisco.
#
# Now lets take into consideration the rest of the requirements:
# 1. Near airports
# 2. Near schools
# 3. Near starbucks
# 4. Near restaurants with vegan options
# 5. Near a basketball court
# 6. Near a pet grooming services for the company dog
#
# For all of these requirements we will use the Foursquare API. To avoid querying it excesively, all queries were done once and the data recovered from them saved in a DataFrame. We will import this data from an exported CSV. The detailed querying process can be seen in the foursquare.py Python Script that produced this file.

# %%
near_office = pd.read_csv('data/venues_near_office.csv')
near_office = near_office.drop(["Unnamed: 0"], axis=1)
near_office
# Out:
#                                          name  distance   latitude  \
# 0                               SF Puppy Love       378  37.779676
# 1                             Doggie Day Spaw       418  37.778665
# 2                        Tefani & So. Dogcare       676  37.787193
# 3                                 Furry Tales      1161  37.776754
# 4                        Tefani & So. Dogcare      1189  37.772824
# ..                                        ...       ...        ...
# 82                   San Francisco Day School      3745  37.778074
# 83           Harvey Milk Civil Rights Academy      3826  37.759027
# 84              Immaculate Conception Academy      3834  37.751725
# 85  San Francisco International Airport (SFO)     18466  37.624123
# 86        Oakland International Airport (OAK)     18478  37.711700
#
#      longitude  category_id          category_name         group
# 0  -122.401321        11134   Pet Grooming Service  Pet Grooming
# 1  -122.402590        11134   Pet Grooming Service  Pet Grooming
# 2  -122.399150        11134   Pet Grooming Service  Pet Grooming
# 3  -122.392943        11134   Pet Grooming Service  Pet Grooming
# 4  -122.410202        11134   Pet Grooming Service  Pet Grooming
# ..         ...          ...                    ...           ...
# 82 -122.446636        12058      Elementary School       Schools
# 83 -122.436406        12058      Elementary School       Schools
# 84 -122.423362        12059            High School       Schools
# 85 -122.395506        19040  International Airport      Airports
# 86 -122.212997        19040  International Airport      Airports
#
# [87 rows x 7 columns]

# %% [markdown]
# Now that we have our nearby venues to cover for all office requirements lets get our final map that shows all these venues and our nerby companies:

# %%
final_map = final_map(sf_center, office_location, near_office)
final_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0aeb53665891bba4ef7e3a313e5cb4fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0aeb53665891bba4ef7e3a313e5cb4fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0aeb53665891bba4ef7e3a313e5cb4fa = L.map(
#                 &quot;map_0aeb53665891bba4ef7e3a313e5cb4fa&quot;,
#                 {
#                     center: [37.72, -122.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ed92fe1907aa0704d4d6b8c8c2d3309 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0aeb53665891bba4ef7e3a313e5cb4fa);
#
#
#             var feature_group_488bcc9a2f32887bfd4da4e90f75c4bc = L.featureGroup(
#                 {}
#             ).addTo(map_0aeb53665891bba4ef7e3a313e5cb4fa);
#
#
#             var marker_4a07348bab1764432308f17b1197f38d = L.marker(
#                 [37.779676, -122.401321],
#                 {}
#             ).addTo(feature_group_488bcc9a2f32887bfd4da4e90f75c4bc);
#
#
#             var icon_7cff1ca94bf2f604d0b71ab8a529389e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4a07348bab1764432308f17b1197f38d.setIcon(icon_7cff1ca94bf2f604d0b71ab8a529389e);
#
#
#             marker_4a07348bab1764432308f17b1197f38d.bindTooltip(
#                 `&lt;div&gt;
#                      SF Puppy Love
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e92f8bce3472c59cd938177a45fc9804 = L.marker(
#                 [37.778665, -122.40259],
#                 {}
#             ).addTo(feature_group_488bcc9a2f32887bfd4da4e90f75c4bc);
#
#
#             var icon_679210a369cd426e22d956263e8d3f85 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e92f8bce3472c59cd938177a45fc9804.setIcon(icon_679210a369cd426e22d956263e8d3f85);
#
#
#             marker_e92f8bce3472c59cd938177a45fc9804.bindTooltip(
#                 `&lt;div&gt;
#                      Doggie Day Spaw
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_de389cb5d68de4ac2f0375c23b75c5b7 = L.marker(
#                 [37.787193, -122.39915],
#                 {}
#             ).addTo(feature_group_488bcc9a2f32887bfd4da4e90f75c4bc);
#
#
#             var icon_3b73cd77b632f0f2239336f333a10e91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_de389cb5d68de4ac2f0375c23b75c5b7.setIcon(icon_3b73cd77b632f0f2239336f333a10e91);
#
#
#             marker_de389cb5d68de4ac2f0375c23b75c5b7.bindTooltip(
#                 `&lt;div&gt;
#                      Tefani &amp; So. Dogcare
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3962ef7425cf8b34cbbf87b8c1b5df0c = L.marker(
#                 [37.776754, -122.392943],
#                 {}
#             ).addTo(feature_group_488bcc9a2f32887bfd4da4e90f75c4bc);
#
#
#             var icon_190146c28d3e0d16ac8edf16c450f5d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3962ef7425cf8b34cbbf87b8c1b5df0c.setIcon(icon_190146c28d3e0d16ac8edf16c450f5d0);
#
#
#             marker_3962ef7425cf8b34cbbf87b8c1b5df0c.bindTooltip(
#                 `&lt;div&gt;
#                      Furry Tales
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_827e3d7fb17fb195cb427f96ee2f15f6 = L.marker(
#                 [37.772824, -122.410202],
#                 {}
#             ).addTo(feature_group_488bcc9a2f32887bfd4da4e90f75c4bc);
#
#
#             var icon_496a490a8aad09d92f33ad0f0fd3d71b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot

# %% [markdown]
# This location satisfies all requirements speciifed!

# %%
office_location
# Out:
# [37.7824, -122.4039]
