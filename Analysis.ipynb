# %% [markdown]
# # Office location selection
#
# First, lets run our python script that defines the functions we will work with:

# %%
# %run -i 'python_scripts/mongo_connection.py'

# %% [markdown]
# Now lets establish the connection to our Mongo Database. For this we will use a function specified in the mongo_connection.py script.

# %%
c = connect_mongo("ironhack","companies")
c
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'companies')

# %% [markdown]
# Our connection was succesful! Now lets query for tech startups and design companies. Again we will use functions defined for these tasks in the mongo_connection.py script since the queries are quite long.

# %%
tech = get_tech_startups(1000000,2008)
# Out:
# Query returned  274  companies.

# %%
design = get_design_companies()
# Out:
# Query returned  965  companies.

# %% [markdown]
# Now that we have our company data, lets process it to eliminate those without coordinates and transform these lists into DataFrames.

# %%
# %run -i 'python_scripts/data_process.py'

# %%
tech_data = get_offices_location(tech)
# Out:
# Received data for  333  companies.
#  202  companies with full location information left.

# %%
design_data = get_offices_location(design)
# Out:
# Received data for  1094  companies.
#  708  companies with full location information left.

# %% [markdown]
# Now that we have data for all tech and design companies that fit our criteria, lets make a heatmap of their location to see which cities have more of both.

# %%
# %run -i 'python_scripts/mapping.py'

# %%
map_heatmap(tech_data, design_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2de9bba42c2ce1f0ea9a10e88ff236e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2de9bba42c2ce1f0ea9a10e88ff236e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2de9bba42c2ce1f0ea9a10e88ff236e = L.map(
#                 &quot;map_e2de9bba42c2ce1f0ea9a10e88ff236e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b8a105a60ae68e1f6c990a55f06d998 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e2de9bba42c2ce1f0ea9a10e88ff236e);
#
#
#             var feature_group_525415e622f71a2aabdb3652e06be73f = L.featureGroup(
#                 {}
#             ).addTo(map_e2de9bba42c2ce1f0ea9a10e88ff236e);
#
#
#             var heat_map_452f8545dfc6c11486774c097e5829a8 = L.heatLayer(
#                 [[51.5499708, -0.1815999], [28.5821195, 77.3266991], [37.775196, -122.419204], [37.4189073, -122.0884286], [48.8952712, 2.4476331], [40.723652, -73.985281], [32.037363, 34.8003705], [47.6257402, -122.3581623], [37.785271, -122.397582], [37.41924, -122.208414], [46.2121463, 6.1503245], [45.546481, -122.9021288], [53.544711, -113.515769], [30.310978, -81.657707], [37.758352, -122.398379], [38.960381, -77.084811], [45.5251, -122.8097], [34.153588, -118.422495], [37.775196, -122.419204], [37.775196, -122.419204], [37.764395, -122.401024], [42.337037, -71.251748], [42.35888, -71.05682], [47.6103008, -122.3399782], [42.3694815, -71.0771871], [34.047312, -118.445243], [37.78691, -122.404403], [40.741594, -73.990468], [32.88945, -117.166929], [32.037363, 34.8003705], [34.0497638, -118.2474287], [34.007112, -118.489748], [37.5252461, -121.9178417], [40.7481039, -74.0353787], [37.552262, -122.292146], [40.744618, -73.987764], [42.2968126, -71.3876282], [37.4104762, -122.0185959], [37.4239496, -122.1011815], [36.9751032, -122.0253784], [39.749671, -104.9998449], [37.7870923, -122
# Lets get GeoJsons for these cities. Rather than looking for defined poligons with the bordes of the city, I created GeoJson files of cirles encompassing these cities. I made them wide enough so that it covered nearby towns so that they would be counted as nearby.

# %%
city_names = ["san_francisco", "los_angeles", "new_york", "miami", "paris", "manchester"]
cities = load_cities(city_names)
cities
# Out:
# {'San_Francisco': <POLYGON ((-122.241 38.23, -122.312 38.227, -122.383 38.219, -122.452 38.205...>,
#  'Los_Angeles': <POLYGON ((-118.113 34.81, -118.207 34.807, -118.3 34.795, -118.392 34.776, ...>,
#  'New_York': <POLYGON ((-73.977 41.103, -74.021 41.102, -74.064 41.097, -74.107 41.089, -...>,
#  'Miami': <POLYGON ((-80.271 26.121, -80.305 26.12, -80.338 26.115, -80.371 26.108, -8...>,
#  'Paris': <POLYGON ((2.354 49.066, 2.322 49.065, 2.292 49.062, 2.261 49.057, 2.232 49....>,
#  'Manchester': <POLYGON ((-2.244 53.593, -2.263 53.593, -2.282 53.591, -2.3 53.589, -2.318 ...>}

# %% [markdown]
# Now that we have our GeoJsons loaded, lets add the city name, based on these GeoJsons, to our DataFrames.
#
# This stepp will check for every office in our Data Frame, if that location is in one of the cities defined by the GeoJsons, it will add that city name to our DataFrame.

# %%
tech_data = add_city_name(tech_data, cities)
# We will also be adding a "tech" identifier in a new column called "type". This will be useful in a future step, where we will consolidate all of our data in a single DataFrame.
tech_data["type"] = "tech"
tech_data.head()
# Out:
#         name office description  office latitude  office longitude  \
# 0    Movirtu        Headquarter        51.549971         -0.181600
# 2    Movirtu       India Office        28.582120         77.326699
# 4     GitHub                           37.775196       -122.419204
# 5  Gridstore          Gridstore        37.418907       -122.088429
# 7  WEEZEVENT      French Office        48.895271          2.447633
#
#             city  type
# 0           None  tech
# 2           None  tech
# 4  San_Francisco  tech
# 5  San_Francisco  tech
# 7          Paris  tech

# %% [markdown]
# Now we will do the same thing for our desgin companies

# %%
design_data = add_city_name(design_data, cities)
design_data["type"] = "design"
design_data.head()
# Out:
#          name  office description  office latitude  office longitude  \
# 0  Technorati                            37.779558       -122.393041
# 1     AddThis       HQ - Virginia        38.926172        -77.245195
# 2     AddThis     New York Office        40.724604        -73.996876
# 3     AddThis  Los Angeles Office        34.026302       -118.380954
# 6     AddThis     Michigan Office        42.557958        -83.167884
#
#             city    type
# 0  San_Francisco  design
# 1           None  design
# 2       New_York  design
# 3    Los_Angeles  design
# 6           None  design

# %% [markdown]
# Now lets join these DataFrames and find out the top cities with more companies.

# %%
full_data = pd.concat([tech_data, design_data], axis=0)
top_cities = full_data.groupby(['city', 'type'])['name'].agg('count').reset_index()
top_cities
# Out:
#             city    type  name
# 0    Los_Angeles  design    46
# 1    Los_Angeles    tech    14
# 2     Manchester  design     3
# 3          Miami  design     7
# 4       New_York  design    80
# 5       New_York    tech    22
# 6          Paris  design    10
# 7          Paris    tech     4
# 8  San_Francisco  design   123
# 9  San_Francisco    tech    58

# %% [markdown]
# Looks like our top 3 cities are San Francisco, New York and Los Angeles.

# %%
top_cities = top_cities.drop([2,3,6,7])
top_cities
# Out:
#             city    type  name
# 0    Los_Angeles  design    46
# 1    Los_Angeles    tech    14
# 4       New_York  design    80
# 5       New_York    tech    22
# 8  San_Francisco  design   123
# 9  San_Francisco    tech    58

# %% [markdown]
# Having narrowed down our search to these 3 cities lets map them.
# First, lets consolidate our data:

# %%
final_data = full_data[full_data['city'].isin(['Los_Angeles', 'New_York', 'San_Francisco'])]
final_data.head()
# Out:
#          name office description  office latitude  office longitude  \
# 4      GitHub                           37.775196       -122.419204
# 5   Gridstore          Gridstore        37.418907       -122.088429
# 8     Kluster    New York Office        40.723652        -73.985281
# 17       Meez                           37.785271       -122.397582
# 18     Gamook               None        37.419240       -122.208414
#
#              city  type
# 4   San_Francisco  tech
# 5   San_Francisco  tech
# 8        New_York  tech
# 17  San_Francisco  tech
# 18  San_Francisco  tech

# %%
top_3_map(final_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_587573820323377c7bcc0b52489cb1ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_587573820323377c7bcc0b52489cb1ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_587573820323377c7bcc0b52489cb1ec = L.map(
#                 &quot;map_587573820323377c7bcc0b52489cb1ec&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d59abae14c2ce7e04ae2bff3f4136034 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_587573820323377c7bcc0b52489cb1ec);
#
#
#             var feature_group_e87f2235c4d6eb75f719c8eac5c332c3 = L.featureGroup(
#                 {}
#             ).addTo(map_587573820323377c7bcc0b52489cb1ec);
#
#
#             var marker_916aa9b8268e38372354b58334606d2e = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_e87f2235c4d6eb75f719c8eac5c332c3);
#
#
#             var icon_c0920c27d8e8b85ecaede1bb2f40a4d2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_916aa9b8268e38372354b58334606d2e.setIcon(icon_c0920c27d8e8b85ecaede1bb2f40a4d2);
#
#
#             marker_916aa9b8268e38372354b58334606d2e.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_02a7fe37ee9cd42231c3c6f32d870573 = L.marker(
#                 [37.4189073, -122.0884286],
#                 {}
#             ).addTo(feature_group_e87f2235c4d6eb75f719c8eac5c332c3);
#
#
#             var icon_21a2ffdf8dca867fe00c693f0a94ffcf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_02a7fe37ee9cd42231c3c6f32d870573.setIcon(icon_21a2ffdf8dca867fe00c693f0a94ffcf);
#
#
#             marker_02a7fe37ee9cd42231c3c6f32d870573.bindTooltip(
#                 `&lt;div&gt;
#                      Gridstore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ac6f2e3693e9e47ef69e955ff61788fc = L.marker(
#                 [40.723652, -73.985281],
#                 {}
#             ).addTo(feature_group_e87f2235c4d6eb75f719c8eac5c332c3);
#
#
#             var icon_3127a93e0def23f384fcf07e8cf3891f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ac6f2e3693e9e47ef69e955ff61788fc.setIcon(icon_3127a93e0def23f384fcf07e8cf3891f);
#
#
#             marker_ac6f2e3693e9e47ef69e955ff61788fc.bindTooltip(
#                 `&lt;div&gt;
#                      Kluster
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3ede781341e3064a74a124b469c02cfb = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_e87f2235c4d6eb75f719c8eac5c332c3);
#
#
#             var icon_a39c98d00153bd28401c6338f88aa0ca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3ede781341e3064a74a124b469c02cfb.setIcon(icon_a39c98d00153bd28401c6338f88aa0ca);
#
#
#             marker_3ede781341e3064a74a124b469c02cfb.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6ddf3b50ae36b68d9a3a0d161a8692e6 = L.marker(
#                 [37.41924, -122.208414],
#                 {}
#             ).addTo(feature_group_e87f2235c4d6eb75f719c8eac5c332c3);
#
#
#             var icon_31f5e7948bacda58efc3856d6854856e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor
