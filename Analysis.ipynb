# %% [markdown]
# # Office location selection
#
# For this project we will determine the best posible location for an office that satisfies all the requirements stated in the project description. Here's a summary:
#
# 1. It must be near tech startups that have raised more than 1MM USD.
# 2. It must be near other companies that do design.
# 3. It must be near schools since 1/3 of employees have at least 1 child.
# 4. It must be near an airport.
# 5. It should be near a Starbucks.
# 6. It should have nearby restaurants with vegan options.
# 7. It should have a basketball court within 10 Km.
# 8. It must have a pet grooming service nearby for the company dog.
#
# For this, we will use the companies Mongo DB provided by crunchbase.
#
# First, lets run our python script that defines the functions we will work with:

# %%
# %run -i 'python_scripts/mongo_connection.py'

# %% [markdown]
# Now lets establish the connection to our Mongo Database. For this we will use a function specified in the mongo_connection.py script.

# %%
c = connect_mongo("ironhack","companies")
c
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'companies')

# %% [markdown]
# Our connection was succesful! Now lets query our companies collection for tech startups and design companies. Again we will use functions defined for these tasks in the mongo_connection.py script since the queries are quite long.

# %%
tech = get_tech_startups(1000000,2008)
# Out:
# Query returned  274  companies.

# %%
design = get_design_companies()
# Out:
# Query returned  965  companies.

# %% [markdown]
# Now that we have our company data, lets process it to eliminate those without coordinates and transform these lists into DataFrames. For this we will use pre-defined functions in our data_process script, lets run it:

# %%
# %run -i 'python_scripts/data_process.py'

# %%
tech_data = get_offices_location(tech)
# Out:
# Received data for  333  companies.
#  202  companies with full location information left.

# %%
design_data = get_offices_location(design)
# Out:
# Received data for  1094  companies.
#  708  companies with full location information left.

# %% [markdown]
# Now that we have data for all tech and design companies that fit our criteria, lets make a heatmap of their location to see which cities have more of both. For this we will load our mappying script since it has functions that will help us map this information.

# %%
# %run -i 'python_scripts/mapping.py'

# %%
map_heatmap(tech_data, design_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0249e88f724eba616371902bfeda8229 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0249e88f724eba616371902bfeda8229&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0249e88f724eba616371902bfeda8229 = L.map(
#                 &quot;map_0249e88f724eba616371902bfeda8229&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f041b175ceef71b260db64de3e27b854 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0249e88f724eba616371902bfeda8229);
#
#
#             var feature_group_8f87113efb06e0be3213dc706ffe3e11 = L.featureGroup(
#                 {}
#             ).addTo(map_0249e88f724eba616371902bfeda8229);
#
#
#             var heat_map_017460952f037e253f2632c4116b3e99 = L.heatLayer(
#                 [[47.6257402, -122.3581623], [32.037363, 34.8003705], [40.723652, -73.985281], [48.8952712, 2.4476331], [37.4189073, -122.0884286], [37.775196, -122.419204], [51.5499708, -0.1815999], [28.5821195, 77.3266991], [53.544711, -113.515769], [45.546481, -122.9021288], [46.2121463, 6.1503245], [37.785271, -122.397582], [37.41924, -122.208414], [37.764395, -122.401024], [37.775196, -122.419204], [34.153588, -118.422495], [37.775196, -122.419204], [45.5251, -122.8097], [38.960381, -77.084811], [37.758352, -122.398379], [30.310978, -81.657707], [34.047312, -118.445243], [42.3694815, -71.0771871], [47.6103008, -122.3399782], [42.35888, -71.05682], [42.337037, -71.251748], [34.007112, -118.489748], [37.5252461, -121.9178417], [34.0497638, -118.2474287], [32.037363, 34.8003705], [32.88945, -117.166929], [37.78691, -122.404403], [40.741594, -73.990468], [37.4239496, -122.1011815], [37.4104762, -122.0185959], [42.2968126, -71.3876282], [40.744618, -73.987764], [40.7481039, -74.0353787], [37.552262, -122.292146], [40.739867, -73.990024], [33.8171, -111.9035], [42.3406534, -71.0680027], [42.318138, -71.24756], [37.384239, -122.012475], [51.5001524, -0.1262362], [42.4236783, -71.2459523], [37.7870923, -122.3999719], [36.9751032, -122.0253784], [39.749671, -104.9998449], [38.6501668, -90.2598684], [40.7272544, -74.0057152], [37.788796, -122.40971], [29.9739941, -90.0822015], [52.5308516, 13.3842605], [40.756054, -73.986951], [40.7450497, -73.9900984], [42.392628, -71.151216], [37.7705096, -122.4015807], [40.5932386, -105.0766501], [40.7481039, -74.0353787], [37.4484914, -122.1802812], [37.7905538, -122.4041485], [37.7893215, -122.4013624], [32.0554, 34.7595], [51.5196135, -0.1020265], [34.005914, -118.488129], [48.868478, 2.339843], [42.3756409, -72.5196907], [37.566879, -122.323895], [52.143886, -106.6634565], [37.5561712, -122.0780632], [12.971606, 77.594376], [40.7185614, -73.998662], [45.546481, -122.9021288], [34.0137151, -118.4660597], [37.7795014, -122.3948712], [29.7847641, -82.4768036], [38.94794, -77.347961], [34.213925, -118.487236], [40.438423, -80.001933], [42.376862, -71.14462], [42.6751888, -71.1469003], [-33.947414, 150.967905], [37.446823, -122.161523], [34.0698494, -118.4054182], [29.973994, -90.082202], [39.9443552, -75.1257381], [34.111471, -118.174878], [32.7161896, -117.168697], [38.257035, -85.717393], [37.420728, -122.2103414], [37.764395, -122.401024], [43.4496954, -80.487328], [37.443058, -122.161674], [40.73343, -73.990967], [37.393536, -122.076747], [26.2032036, -80.1510951], [49.2851733, -123.0952381], [51.8205815, 0.0118608], [30.297775, -97.762921], [42.3853985, -83.5069834], [42.3647559, -71.1032591], [37.7770719, -122.3966273], [37.4280877, -122.143368], [37.444531, -122.163352], [37.445335, -122.15833], [37.3229727, -122.0385792], [30.269004, -97.740395], [41.8965162, -87.643622], [47.490346, 19.059078], [37.444332, -122.161018], [42.275263, -71.24762], [39.749671, -104.9998449], [37.523194, -122.259179], [42.3624253, -71.116031], [43.644678, -79.567221], [37.775196, -122.419204], [43.6910137, -70.2694636], [40.4225487, -3.6830316], [51.5480857, 0.6553168], [47.3912899, 8.5082891], [37.503147, -122.211435], [37.770067, -122.407603], [37.6656476, -122.3843489], [37.39458, -121.928393], [40.740231, -73.985433], [47.676762, -122.2049192], [40.740308, -74.007199], [40.532969, -80.010645], [47.6220245, -122.3350847], [34.052187, -118.243425], [37.781265, -122.393229], [52.132633, 5.291266], [37.7900992, -122.4021988], [21.303049, -157.78907], [51.51819, -0.208979], [37.78691, -122.404403], [40.741594, -73.990468], [37.7870923, -122.3999719], [41.792265, 1.996567], [41.3279176, -73.2435522], [48.8318497, 2.3389

# %% [markdown]
# Browsing this heatmap, it looks like our offices should be either in San francisco, Los Angeles, New york, Miami, Paris or Manchester. Let's get GeoJsons for these cities.
#
# Rather than looking for defined poligons with the borders of these cities, I created GeoJson files of circles encompassing these cities and their surrounding area. I made them wide enough so that they covered nearby towns that also have important amounts of companies.

# %%
city_names = ["san_francisco", "los_angeles", "new_york", "miami", "paris", "manchester"]
cities = load_cities(city_names)
cities
# Out:
# {'San_Francisco': <POLYGON ((-122.241 38.23, -122.312 38.227, -122.383 38.219, -122.452 38.205...>,
#  'Los_Angeles': <POLYGON ((-118.113 34.81, -118.207 34.807, -118.3 34.795, -118.392 34.776, ...>,
#  'New_York': <POLYGON ((-73.977 41.103, -74.021 41.102, -74.064 41.097, -74.107 41.089, -...>,
#  'Miami': <POLYGON ((-80.271 26.121, -80.305 26.12, -80.338 26.115, -80.371 26.108, -8...>,
#  'Paris': <POLYGON ((2.354 49.066, 2.322 49.065, 2.292 49.062, 2.261 49.057, 2.232 49....>,
#  'Manchester': <POLYGON ((-2.244 53.593, -2.263 53.593, -2.282 53.591, -2.3 53.589, -2.318 ...>}

# %% [markdown]
# Now that we have our GeoJsons loaded, lets add the city name to our DataFrames, based on these GeoJsons.
#
# This stepp will check for every office in our Data Frame, if that location is in one of the cirlces defined by the GeoJsons, it will add that city name to our DataFrame.

# %%
tech_data = add_city_name(tech_data, cities)
# We will also be adding a "tech" identifier in a new column called "type". This will be useful in a future step, where we will consolidate all of our data in a single DataFrame.
tech_data["type"] = "tech"
tech_data.head()
# Out:
#         name   office description  office latitude  office longitude  \
# 0   Kashless   World Headquarters        47.625740       -122.358162
# 2    Tweegee  Tweegee Develpoment        32.037363         34.800370
# 6    Kluster      New York Office        40.723652        -73.985281
# 8  WEEZEVENT        French Office        48.895271          2.447633
# 9  Gridstore            Gridstore        37.418907       -122.088429
#
#             city  type
# 0           None  tech
# 2           None  tech
# 6       New_York  tech
# 8          Paris  tech
# 9  San_Francisco  tech

# %% [markdown]
# Now we will do the same thing for our desgin companies

# %%
design_data = add_city_name(design_data, cities)
design_data["type"] = "design"
design_data.head()
# Out:
#          name  office description  office latitude  office longitude  \
# 0  Technorati                            37.779558       -122.393041
# 1     AddThis       HQ - Virginia        38.926172        -77.245195
# 2     AddThis     New York Office        40.724604        -73.996876
# 3     AddThis  Los Angeles Office        34.026302       -118.380954
# 6     AddThis     Michigan Office        42.557958        -83.167884
#
#             city    type
# 0  San_Francisco  design
# 1           None  design
# 2       New_York  design
# 3    Los_Angeles  design
# 6           None  design

# %% [markdown]
# Now lets join these DataFrames and find out the top cities with more companies.

# %%
full_data = pd.concat([tech_data, design_data], axis=0)
top_cities = full_data.groupby(['city', 'type'])['name'].agg('count').reset_index()
top_cities
# Out:
#             city    type  name
# 0    Los_Angeles  design    46
# 1    Los_Angeles    tech    14
# 2     Manchester  design     3
# 3          Miami  design     7
# 4       New_York  design    80
# 5       New_York    tech    22
# 6          Paris  design    10
# 7          Paris    tech     4
# 8  San_Francisco  design   123
# 9  San_Francisco    tech    58

# %% [markdown]
# Looks like our top 3 cities with more tech and design companies are San Francisco, New York and Los Angeles. Lets drop the rest:

# %%
top_cities = top_cities.drop([2,3,6,7])
top_cities
# Out:
#             city    type  name
# 0    Los_Angeles  design    46
# 1    Los_Angeles    tech    14
# 4       New_York  design    80
# 5       New_York    tech    22
# 8  San_Francisco  design   123
# 9  San_Francisco    tech    58

# %% [markdown]
# Having narrowed down our search to these 3 cities lets map them.
# First, lets consolidate our data:

# %%
final_data = full_data[full_data['city'].isin(['Los_Angeles', 'New_York', 'San_Francisco'])]
final_data.head()
# Out:
#          name office description  office latitude  office longitude  \
# 6     Kluster    New York Office        40.723652        -73.985281
# 9   Gridstore          Gridstore        37.418907       -122.088429
# 10     GitHub                           37.775196       -122.419204
# 24       Meez                           37.785271       -122.397582
# 25     Gamook               None        37.419240       -122.208414
#
#              city  type
# 6        New_York  tech
# 9   San_Francisco  tech
# 10  San_Francisco  tech
# 24  San_Francisco  tech
# 25  San_Francisco  tech

# %% [markdown]
# Now lets map our 3 cities:

# %%
top_3_map = top_3_map(final_data)
top_3_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81dd89d307fdc80a37a11cc6e5c20fb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81dd89d307fdc80a37a11cc6e5c20fb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81dd89d307fdc80a37a11cc6e5c20fb1 = L.map(
#                 &quot;map_81dd89d307fdc80a37a11cc6e5c20fb1&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b619d8feef408933eb5face63a50ed14 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81dd89d307fdc80a37a11cc6e5c20fb1);
#
#
#             var feature_group_6603b33bf2eb89cda6044dda2b963ddd = L.featureGroup(
#                 {}
#             ).addTo(map_81dd89d307fdc80a37a11cc6e5c20fb1);
#
#
#             var marker_26da68209b08d9bff69a81da1f194b6d = L.marker(
#                 [40.723652, -73.985281],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_4cf85c0ba445dda0cc44e9303f8dba9e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_26da68209b08d9bff69a81da1f194b6d.setIcon(icon_4cf85c0ba445dda0cc44e9303f8dba9e);
#
#
#             marker_26da68209b08d9bff69a81da1f194b6d.bindTooltip(
#                 `&lt;div&gt;
#                      Kluster
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_38960fa8a73221389cb7c9c50dbc6e95 = L.marker(
#                 [37.4189073, -122.0884286],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_7a1de45f816148aa163c1d69918cbc7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_38960fa8a73221389cb7c9c50dbc6e95.setIcon(icon_7a1de45f816148aa163c1d69918cbc7b);
#
#
#             marker_38960fa8a73221389cb7c9c50dbc6e95.bindTooltip(
#                 `&lt;div&gt;
#                      Gridstore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a5f4750a564128110dc47b8f74aff255 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_e9b7fd78849ac99fd1ad81bd971ccba2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a5f4750a564128110dc47b8f74aff255.setIcon(icon_e9b7fd78849ac99fd1ad81bd971ccba2);
#
#
#             marker_a5f4750a564128110dc47b8f74aff255.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c74d089b9d4c77ca4f8fb69a115589a8 = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_07a535feda0ec0b6dccefbc8621b9dd4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c74d089b9d4c77ca4f8fb69a115589a8.setIcon(icon_07a535feda0ec0b6dccefbc8621b9dd4);
#
#
#             marker_c74d089b9d4c77ca4f8fb69a115589a8.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_117845a9ca2f2595678f3164b7b1705a = L.marker(
#                 [37.41924, -122.208414],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_6308f14e28581a9e3bda21475c726cfd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor

# %% [markdown]
# Browsing this map, lets focus on San Francisco since it is the city with most companies.

# %%
top_3_map.fit_bounds([[37.8,-122.4],[37.5,-122.1]], padding=(4,4))
top_3_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81dd89d307fdc80a37a11cc6e5c20fb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81dd89d307fdc80a37a11cc6e5c20fb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81dd89d307fdc80a37a11cc6e5c20fb1 = L.map(
#                 &quot;map_81dd89d307fdc80a37a11cc6e5c20fb1&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b619d8feef408933eb5face63a50ed14 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81dd89d307fdc80a37a11cc6e5c20fb1);
#
#
#             var feature_group_6603b33bf2eb89cda6044dda2b963ddd = L.featureGroup(
#                 {}
#             ).addTo(map_81dd89d307fdc80a37a11cc6e5c20fb1);
#
#
#             var marker_26da68209b08d9bff69a81da1f194b6d = L.marker(
#                 [40.723652, -73.985281],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_4cf85c0ba445dda0cc44e9303f8dba9e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_26da68209b08d9bff69a81da1f194b6d.setIcon(icon_4cf85c0ba445dda0cc44e9303f8dba9e);
#
#
#             marker_26da68209b08d9bff69a81da1f194b6d.bindTooltip(
#                 `&lt;div&gt;
#                      Kluster
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_38960fa8a73221389cb7c9c50dbc6e95 = L.marker(
#                 [37.4189073, -122.0884286],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_7a1de45f816148aa163c1d69918cbc7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_38960fa8a73221389cb7c9c50dbc6e95.setIcon(icon_7a1de45f816148aa163c1d69918cbc7b);
#
#
#             marker_38960fa8a73221389cb7c9c50dbc6e95.bindTooltip(
#                 `&lt;div&gt;
#                      Gridstore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a5f4750a564128110dc47b8f74aff255 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_e9b7fd78849ac99fd1ad81bd971ccba2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a5f4750a564128110dc47b8f74aff255.setIcon(icon_e9b7fd78849ac99fd1ad81bd971ccba2);
#
#
#             marker_a5f4750a564128110dc47b8f74aff255.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c74d089b9d4c77ca4f8fb69a115589a8 = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_07a535feda0ec0b6dccefbc8621b9dd4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c74d089b9d4c77ca4f8fb69a115589a8.setIcon(icon_07a535feda0ec0b6dccefbc8621b9dd4);
#
#
#             marker_c74d089b9d4c77ca4f8fb69a115589a8.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_117845a9ca2f2595678f3164b7b1705a = L.marker(
#                 [37.41924, -122.208414],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_6308f14e28581a9e3bda21475c726cfd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor

# %% [markdown]
# Let's find out the point that is closest to all of our companies. I'll calculate the mean coordinate for our tech companies and for our design companies separately and add this to our map:

# %%
sf_middle_tech = mean_coordinates(final_data[(final_data["city"] == 'San_Francisco')&(final_data["type"] == 'tech')])
sf_middle_design = mean_coordinates(final_data[(final_data["city"] == 'San_Francisco')&(final_data["type"] == 'design')])

add_marker("sf_tech_center","orange","computer",sf_middle_tech,top_3_map)
add_marker("sf_design_center","red","fa-shopping-bag",sf_middle_design,top_3_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81dd89d307fdc80a37a11cc6e5c20fb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81dd89d307fdc80a37a11cc6e5c20fb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81dd89d307fdc80a37a11cc6e5c20fb1 = L.map(
#                 &quot;map_81dd89d307fdc80a37a11cc6e5c20fb1&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b619d8feef408933eb5face63a50ed14 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_81dd89d307fdc80a37a11cc6e5c20fb1);
#
#
#             var feature_group_6603b33bf2eb89cda6044dda2b963ddd = L.featureGroup(
#                 {}
#             ).addTo(map_81dd89d307fdc80a37a11cc6e5c20fb1);
#
#
#             var marker_26da68209b08d9bff69a81da1f194b6d = L.marker(
#                 [40.723652, -73.985281],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_4cf85c0ba445dda0cc44e9303f8dba9e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_26da68209b08d9bff69a81da1f194b6d.setIcon(icon_4cf85c0ba445dda0cc44e9303f8dba9e);
#
#
#             marker_26da68209b08d9bff69a81da1f194b6d.bindTooltip(
#                 `&lt;div&gt;
#                      Kluster
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_38960fa8a73221389cb7c9c50dbc6e95 = L.marker(
#                 [37.4189073, -122.0884286],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_7a1de45f816148aa163c1d69918cbc7b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_38960fa8a73221389cb7c9c50dbc6e95.setIcon(icon_7a1de45f816148aa163c1d69918cbc7b);
#
#
#             marker_38960fa8a73221389cb7c9c50dbc6e95.bindTooltip(
#                 `&lt;div&gt;
#                      Gridstore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a5f4750a564128110dc47b8f74aff255 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_e9b7fd78849ac99fd1ad81bd971ccba2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a5f4750a564128110dc47b8f74aff255.setIcon(icon_e9b7fd78849ac99fd1ad81bd971ccba2);
#
#
#             marker_a5f4750a564128110dc47b8f74aff255.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c74d089b9d4c77ca4f8fb69a115589a8 = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_07a535feda0ec0b6dccefbc8621b9dd4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c74d089b9d4c77ca4f8fb69a115589a8.setIcon(icon_07a535feda0ec0b6dccefbc8621b9dd4);
#
#
#             marker_c74d089b9d4c77ca4f8fb69a115589a8.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_117845a9ca2f2595678f3164b7b1705a = L.marker(
#                 [37.41924, -122.208414],
#                 {}
#             ).addTo(feature_group_6603b33bf2eb89cda6044dda2b963ddd);
#
#
#             var icon_6308f14e28581a9e3bda21475c726cfd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor

# %% [markdown]
# It looks like our centers lie in the middle of the bay. This is due to the fact that SF has a city center and nearby cities also have a lot of tech companies. Both of these areas surround the San Francisco Bay.
#
# Lets split our analysis in two, the SF city center and southern nearby cities.
#
# First, lets get new GeoJsons and find out many companies are in each sub divison.

# %%
city_names = ["sf_center", "sf_south"]
sf_cities = load_cities(city_names)
sf_cities
# Out:
# {'Sf_Center': <POLYGON ((-122.419 37.883, -122.432 37.883, -122.445 37.881, -122.457 37.87...>,
#  'Sf_South': <POLYGON ((-122.406 37.569, -122.355 37.518, -122.3 37.486, -122.241 37.448,...>}

# %% [markdown]
# Let's create a new DF just for SF center and SF south

# %%
sf_center = final_data[final_data['city'] == "San_Francisco"]
sf_south = sf_center

# %% [markdown]
# From these new data sets we will asign new city names based on their location and our new disctintion.

# %%
sf_center = add_city_name(sf_center, sf_cities)
sf_south = add_city_name(sf_south, sf_cities)
sf_center = sf_center[sf_center["city"]=="Sf_Center"]
sf_center.sample(5)
# Out:
# /Users/kike/Documents/Personal/Educación/IronHack/Module 1/Week 4/project-III-geospatial-data/python_scripts/data_process.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'] = city_names
#            name      office description  office latitude  office longitude  \
# 110   Podaddies                                37.772640       -122.409915
# 28    Pixelpipe      World Headquarters        37.764395       -122.401024
# 293     GoingOn  GoingOn Networks, Inc.        37.782263       -122.392142
# 216     Coveroo            Headquarters        37.770067       -122.407603
# 427  trueAnthem         Mailing Address        37.805989       -122.409915
#
#           city    type
# 110  Sf_Center  design
# 28   Sf_Center    tech
# 293  Sf_Center    tech
# 216  Sf_Center    tech
# 427  Sf_Center  design

# %%
sf_south = sf_south[sf_south["city"]=="Sf_South"]
sf_south.sample(5)
# Out:
#            name office description  office latitude  office longitude  \
# 441    Buysight                           37.425359       -122.138963
# 115       Fixya                           37.566879       -122.323895
# 326     iCharts        Main Office        37.384239       -122.012475
# 63      Delphix                           37.423950       -122.101181
# 317  JellyCloud               None        37.485786       -122.206246
#
#          city    type
# 441  Sf_South  design
# 115  Sf_South    tech
# 326  Sf_South    tech
# 63   Sf_South    tech
# 317  Sf_South  design

# %% [markdown]
# Now lets find out the center for both categories and both cities and map them all. Lets start a fresh new map for this:

# %%
sf_map = sf_map(sf_center, sf_south)
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a85ce0a638f359e6625a375b7dccfa57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a85ce0a638f359e6625a375b7dccfa57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a85ce0a638f359e6625a375b7dccfa57 = L.map(
#                 &quot;map_a85ce0a638f359e6625a375b7dccfa57&quot;,
#                 {
#                     center: [37.6, -122.15],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_625a36a534daec80f84a29ff54fbeabe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a85ce0a638f359e6625a375b7dccfa57);
#
#
#             var feature_group_92092f2c933564a3f3aaee80e42d14e1 = L.featureGroup(
#                 {}
#             ).addTo(map_a85ce0a638f359e6625a375b7dccfa57);
#
#
#             var marker_5de14ed95981f41512d6a0b6a8137e53 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_92092f2c933564a3f3aaee80e42d14e1);
#
#
#             var icon_de8d421d545134d5675782532c0ef8dd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5de14ed95981f41512d6a0b6a8137e53.setIcon(icon_de8d421d545134d5675782532c0ef8dd);
#
#
#             marker_5de14ed95981f41512d6a0b6a8137e53.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d3cca200cc258ede39e1f30cf4be468c = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_92092f2c933564a3f3aaee80e42d14e1);
#
#
#             var icon_60972199dcc4c21a9696e1a7cf302d68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d3cca200cc258ede39e1f30cf4be468c.setIcon(icon_60972199dcc4c21a9696e1a7cf302d68);
#
#
#             marker_d3cca200cc258ede39e1f30cf4be468c.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_72f18753ddf29eec6d353b1dfc765b99 = L.marker(
#                 [37.764395, -122.401024],
#                 {}
#             ).addTo(feature_group_92092f2c933564a3f3aaee80e42d14e1);
#
#
#             var icon_ba663d1c4269f35ddb0dc164c27881f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_72f18753ddf29eec6d353b1dfc765b99.setIcon(icon_ba663d1c4269f35ddb0dc164c27881f1);
#
#
#             marker_72f18753ddf29eec6d353b1dfc765b99.bindTooltip(
#                 `&lt;div&gt;
#                      Pixelpipe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0e0f97ee15459aee0ed72dcbea064306 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_92092f2c933564a3f3aaee80e42d14e1);
#
#
#             var icon_50624830ca1fdc6a9620f105aa5e65fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.5, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0e0f97ee15459aee0ed72dcbea064306.setIcon(icon_50624830ca1fdc6a9620f105aa5e65fd);
#
#
#             marker_0e0f97ee15459aee0ed72dcbea064306.bindTooltip(
#                 `&lt;div&gt;
#                      Stitcher
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0634e6a2d2df01fc02b4b60f215e7759 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_92092f2c933564a3f3aaee80e42d14e1);
#
#
#             var icon_fefbdc17cb057a8e7bca963c06499e18 = L.AwesomeMarkers.icon(

# %% [markdown]
# Great! Looks like both sectors have mean coordinates pretty close to each other.
# Let's find out which one has more companies:

# %%
sf = pd.concat([sf_center, sf_south], axis=0)
sf.groupby(["city","type"])["name"].agg("count").reset_index()
# Out:
#         city    type  name
# 0  Sf_Center  design    67
# 1  Sf_Center    tech    26
# 2   Sf_South  design    45
# 3   Sf_South    tech    25

# %% [markdown]
# Since the San Francisco City Center has more companies and they are all closer together, let's focus on this area for our location.
#
# Now we will find out the mean coordinates between the centers of both sectors. This will define the most desireable location for our office.

# %%
sf_center_tech_mean = mean_coordinates(sf_center[(sf_center["type"] == 'tech')])
sf_center_design_mean = mean_coordinates(sf_center[(sf_center["type"] == 'design')])

office_location = mean_coordinates_raw([sf_center_tech_mean,sf_center_design_mean])
office_location
# Out:
# [37.7824, -122.4039]

# %% [markdown]
# Great! Now that we have our desired location lets see how it sits on the map in relation to our other companies

# %%
sf_map_2 = sf_map_2(sf_center, office_location)
sf_map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4afef9e2fbaa3628952c097bb78beb0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4afef9e2fbaa3628952c097bb78beb0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4afef9e2fbaa3628952c097bb78beb0e = L.map(
#                 &quot;map_4afef9e2fbaa3628952c097bb78beb0e&quot;,
#                 {
#                     center: [37.767, -122.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf5e39ab56a0d6ecce13b31b6cc8f2c7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4afef9e2fbaa3628952c097bb78beb0e);
#
#
#             var feature_group_b941266714cb98f0e1e856574e38e44d = L.featureGroup(
#                 {}
#             ).addTo(map_4afef9e2fbaa3628952c097bb78beb0e);
#
#
#             var marker_e86dc5f0c8c087530ab2b58d1130964e = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_b941266714cb98f0e1e856574e38e44d);
#
#
#             var icon_a9349cae351618992decf5750141a53f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e86dc5f0c8c087530ab2b58d1130964e.setIcon(icon_a9349cae351618992decf5750141a53f);
#
#
#             marker_e86dc5f0c8c087530ab2b58d1130964e.bindTooltip(
#                 `&lt;div&gt;
#                      GitHub
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9a4f4aaa8f9a20aa26824d82991ba737 = L.marker(
#                 [37.785271, -122.397582],
#                 {}
#             ).addTo(feature_group_b941266714cb98f0e1e856574e38e44d);
#
#
#             var icon_79f671a36d23db11676a025226f1ac80 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9a4f4aaa8f9a20aa26824d82991ba737.setIcon(icon_79f671a36d23db11676a025226f1ac80);
#
#
#             marker_9a4f4aaa8f9a20aa26824d82991ba737.bindTooltip(
#                 `&lt;div&gt;
#                      Meez
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f69efe89e478b9737b1339adf72cd510 = L.marker(
#                 [37.764395, -122.401024],
#                 {}
#             ).addTo(feature_group_b941266714cb98f0e1e856574e38e44d);
#
#
#             var icon_02b61845dc869576b9e3c0d0b33aa3c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f69efe89e478b9737b1339adf72cd510.setIcon(icon_02b61845dc869576b9e3c0d0b33aa3c0);
#
#
#             marker_f69efe89e478b9737b1339adf72cd510.bindTooltip(
#                 `&lt;div&gt;
#                      Pixelpipe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_12ad1f38fab6f775aa7c25cd6154e723 = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_b941266714cb98f0e1e856574e38e44d);
#
#
#             var icon_1154c0f715e126e57e4745625272d74b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.1, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_12ad1f38fab6f775aa7c25cd6154e723.setIcon(icon_1154c0f715e126e57e4745625272d74b);
#
#
#             marker_12ad1f38fab6f775aa7c25cd6154e723.bindTooltip(
#                 `&lt;div&gt;
#                      Stitcher
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d8b58c36042419f836840bf7ac4bf43c = L.marker(
#                 [37.775196, -122.419204],
#                 {}
#             ).addTo(feature_group_b941266714cb98f0e1e856574e38e44d);
#
#
#             var icon_744b5d79837f930f855d9c32d5237d06 = L.AwesomeMarkers.icon(

# %% [markdown]
# Awesome! Looks like our office is right in the center of San Francisco.
#
# Now lets take into consideration the rest of the requirements:
# 1. Near airports
# 2. Near schools
# 3. Near starbucks
# 4. Near restaurants with vegan options
# 5. Near a basketball court
# 6. Near a pet grooming services for the company dog
#
# For all of these requirements we will use the Foursquare API. To avoid querying it excesively, all queries were done once and the data recovered from them saved in a DataFrame. We will import this data from an exported CSV. The detailed querying process can be seen in the foursquare.py Python Script that produced this file.

# %%
near_office = pd.read_csv('data/venues_near_office.csv')
near_office = near_office.drop(["Unnamed: 0"], axis=1)
near_office
# Out:
#                                          name  distance   latitude  \
# 0                               SF Puppy Love       378  37.779676
# 1                             Doggie Day Spaw       418  37.778665
# 2                        Tefani & So. Dogcare       676  37.787193
# 3                                 Furry Tales      1161  37.776754
# 4                        Tefani & So. Dogcare      1189  37.772824
# ..                                        ...       ...        ...
# 82                   San Francisco Day School      3745  37.778074
# 83           Harvey Milk Civil Rights Academy      3826  37.759027
# 84              Immaculate Conception Academy      3834  37.751725
# 85  San Francisco International Airport (SFO)     18466  37.624123
# 86        Oakland International Airport (OAK)     18478  37.711700
#
#      longitude  category_id          category_name         group
# 0  -122.401321        11134   Pet Grooming Service  Pet Grooming
# 1  -122.402590        11134   Pet Grooming Service  Pet Grooming
# 2  -122.399150        11134   Pet Grooming Service  Pet Grooming
# 3  -122.392943        11134   Pet Grooming Service  Pet Grooming
# 4  -122.410202        11134   Pet Grooming Service  Pet Grooming
# ..         ...          ...                    ...           ...
# 82 -122.446636        12058      Elementary School       Schools
# 83 -122.436406        12058      Elementary School       Schools
# 84 -122.423362        12059            High School       Schools
# 85 -122.395506        19040  International Airport      Airports
# 86 -122.212997        19040  International Airport      Airports
#
# [87 rows x 7 columns]

# %% [markdown]
# Now that we have our nearby venues to cover for all office requirements lets get our final map that shows all these venues and our nerby companies:

# %%
final_map = final_map(sf_center, office_location, near_office)
final_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c44a56d423cfb611d5ddfbcf429ab78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c44a56d423cfb611d5ddfbcf429ab78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c44a56d423cfb611d5ddfbcf429ab78 = L.map(
#                 &quot;map_3c44a56d423cfb611d5ddfbcf429ab78&quot;,
#                 {
#                     center: [37.72, -122.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7b26bf6d99bb7931a2ec8206f53c466 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3c44a56d423cfb611d5ddfbcf429ab78);
#
#
#             var feature_group_4b097e8937948d240f7d5b2ebefc8cf3 = L.featureGroup(
#                 {}
#             ).addTo(map_3c44a56d423cfb611d5ddfbcf429ab78);
#
#
#             var marker_85d97799be42996b72188740218a91bb = L.marker(
#                 [37.779676, -122.401321],
#                 {}
#             ).addTo(feature_group_4b097e8937948d240f7d5b2ebefc8cf3);
#
#
#             var icon_f71e769e3955d744369b4f2362b23ec6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_85d97799be42996b72188740218a91bb.setIcon(icon_f71e769e3955d744369b4f2362b23ec6);
#
#
#             marker_85d97799be42996b72188740218a91bb.bindTooltip(
#                 `&lt;div&gt;
#                      SF Puppy Love
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1354a6624a150c07e01609c7569dcbd3 = L.marker(
#                 [37.778665, -122.40259],
#                 {}
#             ).addTo(feature_group_4b097e8937948d240f7d5b2ebefc8cf3);
#
#
#             var icon_1632fe84f8c2e425e4b4a4e4759c72fb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1354a6624a150c07e01609c7569dcbd3.setIcon(icon_1632fe84f8c2e425e4b4a4e4759c72fb);
#
#
#             marker_1354a6624a150c07e01609c7569dcbd3.bindTooltip(
#                 `&lt;div&gt;
#                      Doggie Day Spaw
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d1fae274a805b077cc68ca75e563fa9d = L.marker(
#                 [37.787193, -122.39915],
#                 {}
#             ).addTo(feature_group_4b097e8937948d240f7d5b2ebefc8cf3);
#
#
#             var icon_88af5a002254051e734b91a2fbe160d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d1fae274a805b077cc68ca75e563fa9d.setIcon(icon_88af5a002254051e734b91a2fbe160d4);
#
#
#             marker_d1fae274a805b077cc68ca75e563fa9d.bindTooltip(
#                 `&lt;div&gt;
#                      Tefani &amp; So. Dogcare
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c6d22c59735811a1526cf063a24f6157 = L.marker(
#                 [37.776754, -122.392943],
#                 {}
#             ).addTo(feature_group_4b097e8937948d240f7d5b2ebefc8cf3);
#
#
#             var icon_d356b98556342288d2311c50dc694594 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c6d22c59735811a1526cf063a24f6157.setIcon(icon_d356b98556342288d2311c50dc694594);
#
#
#             marker_c6d22c59735811a1526cf063a24f6157.bindTooltip(
#                 `&lt;div&gt;
#                      Furry Tales
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_803006435fe4f5a298065b8757712cd3 = L.marker(
#                 [37.772824, -122.410202],
#                 {}
#             ).addTo(feature_group_4b097e8937948d240f7d5b2ebefc8cf3);
#
#
#             var icon_15f8fd74a629801f57aadf0d3ef30036 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot

# %% [markdown]
# This location satisfies all requirements speciifed!

# %%
office_location
# Out:
# [37.7824, -122.4039]
